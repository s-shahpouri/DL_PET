# %%
import os
import tempfile
from glob import glob
import numpy as np
import nibabel as nib
import torch
import monai
from monai.config import print_config
from monai.networks.nets import UNet
from monai.losses import DiceLoss
from monai.data import DataLoader, CacheDataset, PatchIterd, GridPatchDataset
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd, ScaleIntensityd, RandRotate90d, 
    EnsureTyped, Resized, SqueezeDimd
)
from monai.inferers import SliceInferer
from monai.metrics import DiceMetric
import matplotlib.pyplot as plt

import glob
monai.utils.set_determinism(seed=0)

# %%
# # Create a 2D UNet with randomly initialized weights for testing purposes

# # 3 layer network with down/upsampling by a factor of 2 at each layer with 2-convolution residual units

# net = UNet(
#     spatial_dims=2,
#     in_channels=1,
#     out_channels=1,
#     channels=(4, 8, 16),
#     strides=(2, 2),
#     num_res_units=2,
# )

# # Initialize a dummy 3D tensor volume with shape (N,C,D,H,W)
# input_volume = torch.ones(1, 1, 64, 256, 256)

# # Create an instance of SliceInferer with roi_size as the 256x256 (HxW) and sliding over D axis
# axial_inferer = SliceInferer(roi_size=(256, 256), sw_batch_size=1, cval=-1, progress=True)

# output = axial_inferer(input_volume, net)

# # Output is a 3D volume with 2D slices aggregated
# print("Axial Inferer Output Shape: ", output.shape)
# # Create an instance of SliceInferer with roi_size as the 64x256 (DxW) and sliding over H axis
# coronal_inferer = SliceInferer(
#     roi_size=(64, 256),
#     sw_batch_size=1,
#     spatial_dim=1,  # Spatial dim to slice along is added here
#     cval=-1,
#     progress=True,
# )

# output = coronal_inferer(input_volume, net)

# # Output is a 3D volume with 2D slices aggregated
# print("Coronal Inferer Output Shape: ", output.shape)

# %%
data_dir = '/homes/zshahpouri/DLP/ASC-PET-001'
directory = '/homes/zshahpouri/DLP/Practic/LOGTEST'
output_dir = '/homes/zshahpouri/DLP/Practic/OUT'

# %%
import math 
train_images = sorted(glob.glob(os.path.join(data_dir, "NAC", "*.nii.gz")))
target_images = sorted(glob.glob(os.path.join(data_dir, "MAC", "*.nii.gz")))

# data_dicts = [{"image": img, "target": tar} for img in train_images]
data_dicts = [{"image": img, "target": tar} for img, tar in zip(train_images, target_images)]


# Calculate split sizes
total_size = len(data_dicts)
train_size = math.floor(total_size * 0.7)
val_size = math.floor(total_size * 0.2)
# The test set gets the remaining data points
test_size = total_size - train_size - val_size

# Split the dataset
train_files = data_dicts[:train_size]
val_files = data_dicts[train_size:(train_size + val_size)]
test_files = data_dicts[(train_size + val_size):]

# %%
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd, Spacingd,
    SpatialPadd, ScaleIntensityd, CenterSpatialCropd, EnsureTyped,
)
# Volume-level preprocessing
train_transforms = Compose([
    LoadImaged(keys=["image", "target"]),
    EnsureChannelFirstd(keys=["image", "target"]),
    Spacingd(keys=["image", "target"], pixdim=(4.07, 4.07), mode= 'bilinear'),
    # SpatialPadd(keys=["image", "target"], spatial_size=[168, 168], mode='constant'),  # Adjust spatial_size as needed
    # CenterSpatialCropd(keys=["image", "target"], roi_size=(168, 168)),  # Ensure uniform size
    EnsureTyped(keys=["image", "target"]),
])
# 3D dataset with preprocessing transforms
volume_ds = monai.data.CacheDataset(data=train_files, transform=train_transforms)
# use batch_size=1 to check the volumes because the input volumes have different shapes
# check_loader = DataLoader(volume_ds, batch_size=1)
# check_data = monai.utils.misc.first(check_loader)
# print("first volume's shape: ", check_data["image"].shape, check_data["target"].shape)
# Out:
# Loading dataset: 100%|██████████| 128/128 [02:48<00:00,  1.32s/it]
# first volume's shape:  torch.Size([1, 1, 168, 168, 272]) torch.Size([1, 1, 168, 168, 272])

# %%
patch_func = PatchIterd(
    keys=["image", "target"],
    patch_size=(None, None, 1),  # Dynamic first two dimensions, 1 slice
    start_pos=(0, 0, 0)
)

patch_transform = Compose([
    SqueezeDimd(keys=["image", "target"], dim=-1),  # Squeeze the last dim
    # Resized(keys=["image", "target"], spatial_size=[168, 168])  # Resize slices
    SpatialPadd(keys=["image", "target"], spatial_size=[168, 168], mode='constant'),  # Adjust spatial_size as needed
    CenterSpatialCropd(keys=["image", "target"], roi_size=(168, 168)),  # Ensure uniform size
])

patch_ds = monai.data.GridPatchDataset(
    data=volume_ds, patch_iter=patch_func, transform=patch_transform, with_coordinates=False
)
shuffle_ds = monai.data.ShuffleBuffer(patch_ds, buffer_size=30, seed=0)
train_loader = DataLoader(
    shuffle_ds,
    batch_size=64,
    num_workers=4,
    pin_memory=torch.cuda.is_available(),
)
check_data = monai.utils.misc.first(train_loader)
print("first patch's shape: ", check_data["image"].shape, check_data["target"].shape)
# Out:
# first patch's shape:  torch.Size([64, 1, 168, 168]) torch.Size([64, 1, 168, 168])

# %%
val_ds = monai.data.Dataset(data=val_files, transform=train_transforms)
val_loader = DataLoader(val_ds, num_workers=1, pin_memory=torch.cuda.is_available())

# %%
starting_epoch = 0
decay_epoch = 5
learning_rate = 0.001


class DecayLR:
    def __init__(self, epochs, offset, decay_epochs):
        epoch_flag = epochs - decay_epochs
        assert (epoch_flag > 0), "Decay must start before the training session ends!"
        self.epochs = epochs
        self.offset = offset
        self.decay_epochs = decay_epochs

    def step(self, epoch):
        return 1.0 - max(0, epoch + self.offset - self.decay_epochs) / (
                self.epochs - self.decay_epochs)

# %%
import torch
import torch.nn as nn
from monai.networks.nets import UNet

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = monai.networks.nets.UNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    channels=(16, 32, 64, 128),
    strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

loss_function = torch.nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), 1e-4)

print('Defining optimizer...')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.5, 0.999))



max_epochs = 300
val_interval = 2
best_metric = float('inf')
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
train_losses = []
val_losses = []
# Define scheduler
print('Defining scheduler...')
lr_lambda = DecayLR(epochs=max_epochs, offset=0, decay_epochs=decay_epoch).step
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lr_lambda)
# Out:
# Defining optimizer...
# Defining scheduler...

# %%
import os
import datetime
from datetime import datetime


class TrainingLogger:
    def __init__(self, directory):
        self.directory = directory
        self.ensure_directory_exists(self.directory)
        self.log_file = self.create_log_file()

    def ensure_directory_exists(self, directory):
        if not os.path.exists(directory):
            os.makedirs(directory)

    def create_log_file(self):
        filename = f"{self.directory}/log_{self.get_date()}.txt"
        return open(filename, "w")

    def get_date(self):

        s = datetime.now()
        date = f"{s.month}_{s.day}_{s.hour}_{s.minute}"
        return date

    def log(self, message):
        print(message)
        self.log_file.write(message + "\n")

    def close(self):
        self.log_file.close()

# %%
from monai.inferers import sliding_window_inference, SliceInferer


class ModelTrainer:
    def __init__(self, model, train_loader, val_loader, optimizer, loss_function, scheduler, max_epochs, val_interval, directory, device):
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.optimizer = optimizer
        self.loss_function = loss_function
        self.scheduler = scheduler  # Add scheduler to the class initialization
        self.max_epochs = max_epochs
        self.val_interval = val_interval
        self.directory = directory
        self.device = device  # Assuming device is passed as a parameter
        self.logger = TrainingLogger(directory)
        self.best_metric = float('inf')
        self.best_metric_epoch = -1


    def log(self):
        self.logger.log(f"train set: {len(train_files)}" )
        self.logger.log(f"validation set: {len(val_files)}")
        self.logger.log(f"max_epochs: {max_epochs}")
        self.logger.log(f"val_interval: {val_interval}")
        self.logger.log(f"model.channels: {model.channels}")


    def train(self):
        for epoch in range(self.max_epochs):
            self.logger.log("-" * 10)
            self.logger.log(f"epoch {epoch + 1}/{self.max_epochs}")

            self.model.train()
            epoch_loss = 0
            step = 0

            for batch_data in self.train_loader:
                step += 1
                inputs, targets = batch_data["image"].to(self.device), batch_data["target"].to(self.device)
                self.optimizer.zero_grad()
                outputs = self.model(inputs)
                loss = self.loss_function(outputs, targets)
                loss.backward()
                self.optimizer.step()

                epoch_loss += loss.item()
                # Inside your training loop
                # self.logger.log(f"{step}, train_loss: {loss.item():.4f}")

            epoch_loss /= step
            self.logger.log(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

            # Step the scheduler here, after the training phase and before the validation phase
            self.scheduler.step()
            self.logger.log(f"Stepped scheduler to epoch {epoch + 1}, current lr: {self.scheduler.get_last_lr()}")

            # Validation phase with SliceInferer
            if (epoch + 1) % self.val_interval == 0:
                self.model.eval()
                val_loss = 0
                # Define roi_size based on your model and data specifics
                # Here, considering 2D slice size
                roi_size = (168, 168)
                sw_batch_size = 4  # You can adjust this based on your system's memory
                
                with torch.no_grad():
                    for val_data in val_loader:
                        val_inputs = val_data["image"].to(self.device)
                        val_targets = val_data["target"].to(self.device)
                        slice_inferer = SliceInferer(
                            roi_size=roi_size,
                            sw_batch_size=sw_batch_size,
                            spatial_dim=1,  # Spatial dim to slice along is defined here
                            device=torch.device("cpu"),
                            padding_mode="replicate",
                        )
                        val_outputs = slice_inferer(val_inputs, model).to("cpu")
                        # Compute validation loss
                        val_loss += self.loss_function(val_outputs, val_targets).item()

                val_loss /= len(self.val_loader)
                self.logger.log(f"Validation loss: {val_loss:.4f}")

                if val_loss < self.best_metric:
                    self.best_metric = val_loss
                    self.best_metric_epoch = epoch + 1
                    self.save_model()

        self.logger.close()

    def save_model(self):
        model_filename = f"model_{self.logger.get_date()}.pth"
        torch.save(self.model.state_dict(), os.path.join(self.directory, model_filename))
        self.logger.log(f"Saved {model_filename} model, best_metric: {self.best_metric:.4f}, epoch: {self.best_metric_epoch}")


    
trainer = ModelTrainer(model, train_loader, val_loader, optimizer, loss_function, scheduler, max_epochs, val_interval,directory, device)
trainer.log()
trainer.train()
# Out:
# train set: 128
# validation set: 36
# max_epochs: 300
# val_interval: 2
# model.channels: (16, 32, 64, 128)
# ----------
# epoch 1/300
# epoch 1 average loss: 0.6591
# Stepped scheduler to epoch 1, current lr: [0.001]
# ----------
# epoch 2/300
# epoch 2 average loss: 0.4051
# Stepped scheduler to epoch 2, current lr: [0.001]
# Validation loss: 0.4135
# Saved model_2_23_13_43.pth model, best_metric: 0.4135, epoch: 2
# ----------
# epoch 3/300
# epoch 3 average loss: 0.3116
# Stepped scheduler to epoch 3, current lr: [0.001]
# ----------
# epoch 4/300
# epoch 4 average loss: 0.2608
# Stepped scheduler to epoch 4, current lr: [0.001]
# Validation loss: 0.2773
# Saved model_2_23_13_46.pth model, best_metric: 0.2773, epoch: 4
# ----------
# epoch 5/300
# epoch 5 average loss: 0.2136
# Stepped scheduler to epoch 5, current lr: [0.001]
# ----------
# epoch 6/300
# epoch 6 average loss: 0.2126
# Stepped scheduler to epoch 6, current lr: [0.0009966101694915254]
# Validation loss: 0.2288
# Saved model_2_23_13_50.pth model, best_metric: 0.2288, epoch: 6
# ----------
# epoch 7/300
# epoch 7 average loss: 0.1674
# Stepped scheduler to epoch 7, current lr: [0.0009932203389830508]
# ----------
# epoch 8/300
# epoch 8 average loss: 0.1537
# Stepped scheduler to epoch 8, current lr: [0.0009898305084745764]
# Validation loss: 0.2172
# Saved model_2_23_13_53.pth model, best_metric: 0.2172, epoch: 8
# ----------
# epoch 9/300
# epoch 9 average loss: 0.1297
# Stepped scheduler to epoch 9, current lr: [0.0009864406779661018]
# ----------
# epoch 10/300
# epoch 10 average loss: 0.1150
# Stepped scheduler to epoch 10, current lr: [0.0009830508474576271]
# Validation loss: 0.2186
# ----------
# epoch 11/300
# epoch 11 average loss: 0.1029
# Stepped scheduler to epoch 11, current lr: [0.0009796610169491525]
# ----------
# epoch 12/300
# epoch 12 average loss: 0.0947
# Stepped scheduler to epoch 12, current lr: [0.000976271186440678]
# Validation loss: 0.2211
# ----------
# epoch 13/300
# epoch 13 average loss: 0.0871
# Stepped scheduler to epoch 13, current lr: [0.0009728813559322034]
# ----------
# epoch 14/300
# epoch 14 average loss: 0.0794
# Stepped scheduler to epoch 14, current lr: [0.0009694915254237289]
# Validation loss: 0.2264
# ----------
# epoch 15/300
# epoch 15 average loss: 0.0752
# Stepped scheduler to epoch 15, current lr: [0.0009661016949152543]
# ----------
# epoch 16/300
# epoch 16 average loss: 0.0718
# Stepped scheduler to epoch 16, current lr: [0.0009627118644067798]
# Validation loss: 0.2311
# ----------
# epoch 17/300
# epoch 17 average loss: 0.0691
# Stepped scheduler to epoch 17, current lr: [0.000959322033898305]
# ----------
# epoch 18/300
# epoch 18 average loss: 0.0690
# Stepped scheduler to epoch 18, current lr: [0.0009559322033898305]
# Validation loss: 0.2363
# ----------
# epoch 19/300
# epoch 19 average loss: 0.0650
# Stepped scheduler to epoch 19, current lr: [0.0009525423728813559]
# ----------
# epoch 20/300
# epoch 20 average loss: 0.0651
# Stepped scheduler to epoch 20, current lr: [0.0009491525423728814]
# Validation loss: 0.2175
# ----------
# epoch 21/300
# epoch 21 average loss: 0.0597
# Stepped scheduler to epoch 21, current lr: [0.0009457627118644068]
# ----------
# epoch 22/300
# epoch 22 average loss: 0.0657
# Stepped scheduler to epoch 22, current lr: [0.0009423728813559323]
# Validation loss: 0.2226
# ----------
# epoch 23/300
# epoch 23 average loss: 0.0692
# Stepped scheduler to epoch 23, current lr: [0.0009389830508474577]
# ----------
# epoch 24/300
# epoch 24 average loss: 0.0585
# Stepped scheduler to epoch 24, current lr: [0.000935593220338983]
# Validation loss: 0.2183
# ----------
# epoch 25/300
# epoch 25 average loss: 0.0528
# Stepped scheduler to epoch 25, current lr: [0.0009322033898305084]
# ----------
# epoch 26/300
# epoch 26 average loss: 0.0524
# Stepped scheduler to epoch 26, current lr: [0.0009288135593220339]
# Validation loss: 0.2279
# ----------
# epoch 27/300
# epoch 27 average loss: 0.0492
# Stepped scheduler to epoch 27, current lr: [0.0009254237288135593]
# ----------
# epoch 28/300
# epoch 28 average loss: 0.0542
# Stepped scheduler to epoch 28, current lr: [0.0009220338983050848]
# Validation loss: 0.2111
# Saved model_2_23_14_25.pth model, best_metric: 0.2111, epoch: 28
# ----------
# epoch 29/300
# epoch 29 average loss: 0.0491
# Stepped scheduler to epoch 29, current lr: [0.0009186440677966102]
# ----------
# epoch 30/300
# epoch 30 average loss: 0.0457
# Stepped scheduler to epoch 30, current lr: [0.0009152542372881356]
# Validation loss: 0.2126
# ----------
# epoch 31/300
# epoch 31 average loss: 0.0426
# Stepped scheduler to epoch 31, current lr: [0.0009118644067796611]
# ----------
# epoch 32/300
# epoch 32 average loss: 0.0426
# Stepped scheduler to epoch 32, current lr: [0.0009084745762711864]
# Validation loss: 0.2190
# ----------
# epoch 33/300
# epoch 33 average loss: 0.0433
# Stepped scheduler to epoch 33, current lr: [0.0009050847457627118]
# ----------
# epoch 34/300
# epoch 34 average loss: 0.0433
# Stepped scheduler to epoch 34, current lr: [0.0009016949152542373]
# Validation loss: 0.2498
# ----------
# epoch 35/300
# epoch 35 average loss: 0.0428
# Stepped scheduler to epoch 35, current lr: [0.0008983050847457628]
# ----------
# epoch 36/300
# epoch 36 average loss: 0.0405
# Stepped scheduler to epoch 36, current lr: [0.0008949152542372882]
# Validation loss: 0.2113
# ----------
# epoch 37/300
# epoch 37 average loss: 0.0386
# Stepped scheduler to epoch 37, current lr: [0.0008915254237288136]
# ----------
# epoch 38/300
# epoch 38 average loss: 0.0386
# Stepped scheduler to epoch 38, current lr: [0.000888135593220339]
# Validation loss: 0.2501
# ----------
# epoch 39/300
# epoch 39 average loss: 0.0444
# Stepped scheduler to epoch 39, current lr: [0.0008847457627118645]
# ----------
# epoch 40/300
# epoch 40 average loss: 0.0406
# Stepped scheduler to epoch 40, current lr: [0.0008813559322033898]
# Validation loss: 0.2105
# Saved model_2_23_14_44.pth model, best_metric: 0.2105, epoch: 40
# ----------
# epoch 41/300
# epoch 41 average loss: 0.0385
# Stepped scheduler to epoch 41, current lr: [0.0008779661016949153]
# ----------
# epoch 42/300
# epoch 42 average loss: 0.0354
# Stepped scheduler to epoch 42, current lr: [0.0008745762711864407]
# Validation loss: 0.2073
# Saved model_2_23_14_47.pth model, best_metric: 0.2073, epoch: 42
# ----------
# epoch 43/300
# epoch 43 average loss: 0.0346
# Stepped scheduler to epoch 43, current lr: [0.0008711864406779662]
# ----------
# epoch 44/300
# epoch 44 average loss: 0.0376
# Stepped scheduler to epoch 44, current lr: [0.0008677966101694915]
# Validation loss: 0.2116
# ----------
# epoch 45/300
# epoch 45 average loss: 0.0343
# Stepped scheduler to epoch 45, current lr: [0.000864406779661017]
# ----------
# epoch 46/300
# epoch 46 average loss: 0.0335
# Stepped scheduler to epoch 46, current lr: [0.0008610169491525424]
# Validation loss: 0.2208
# ----------
# epoch 47/300
# epoch 47 average loss: 0.0325
# Stepped scheduler to epoch 47, current lr: [0.0008576271186440678]
# ----------
# epoch 48/300
# epoch 48 average loss: 0.0306
# Stepped scheduler to epoch 48, current lr: [0.0008542372881355932]
# Validation loss: 0.2060
# Saved model_2_23_14_56.pth model, best_metric: 0.2060, epoch: 48
# ----------
# epoch 49/300
# epoch 49 average loss: 0.0318
# Stepped scheduler to epoch 49, current lr: [0.0008508474576271187]
# ----------
# epoch 50/300
# epoch 50 average loss: 0.0312
# Stepped scheduler to epoch 50, current lr: [0.000847457627118644]
# Validation loss: 0.2206
# ----------
# epoch 51/300
# epoch 51 average loss: 0.0303
# Stepped scheduler to epoch 51, current lr: [0.0008440677966101695]
# ----------
# epoch 52/300
# epoch 52 average loss: 0.0296
# Stepped scheduler to epoch 52, current lr: [0.000840677966101695]
# Validation loss: 0.2205
# ----------
# epoch 53/300
# epoch 53 average loss: 0.0277
# Stepped scheduler to epoch 53, current lr: [0.0008372881355932204]
# ----------
# epoch 54/300
# epoch 54 average loss: 0.0282
# Stepped scheduler to epoch 54, current lr: [0.0008338983050847458]
# Validation loss: 0.2204
# ----------
# epoch 55/300
# epoch 55 average loss: 0.2757
# Stepped scheduler to epoch 55, current lr: [0.0008305084745762712]
# ----------
# epoch 56/300
# epoch 56 average loss: 0.1324
# Stepped scheduler to epoch 56, current lr: [0.0008271186440677967]
# Validation loss: 0.2524
# ----------
# epoch 57/300
# epoch 57 average loss: 0.0601
# Stepped scheduler to epoch 57, current lr: [0.000823728813559322]
# ----------
# epoch 58/300
# epoch 58 average loss: 0.0418
# Stepped scheduler to epoch 58, current lr: [0.0008203389830508474]
# Validation loss: 0.2321
# ----------
# epoch 59/300
# epoch 59 average loss: 0.0341
# Stepped scheduler to epoch 59, current lr: [0.0008169491525423729]
# ----------
# epoch 60/300
# epoch 60 average loss: 0.0317
# Stepped scheduler to epoch 60, current lr: [0.0008135593220338984]
# Validation loss: 0.2213
# ----------
# epoch 61/300
# epoch 61 average loss: 0.0303
# Stepped scheduler to epoch 61, current lr: [0.0008101694915254238]
# ----------
# epoch 62/300
# epoch 62 average loss: 0.0315
# Stepped scheduler to epoch 62, current lr: [0.0008067796610169491]
# Validation loss: 0.2266
# ----------
# epoch 63/300
# epoch 63 average loss: 0.0307
# Stepped scheduler to epoch 63, current lr: [0.0008033898305084745]
# ----------
# epoch 64/300
# epoch 64 average loss: 0.0283
# Stepped scheduler to epoch 64, current lr: [0.0008]
# Validation loss: 0.2218
# ----------
# epoch 65/300
# epoch 65 average loss: 0.0276
# Stepped scheduler to epoch 65, current lr: [0.0007966101694915254]
# ----------
# epoch 66/300
# epoch 66 average loss: 0.0279
# Stepped scheduler to epoch 66, current lr: [0.0007932203389830509]
# Validation loss: 0.2243
# ----------
# epoch 67/300
# epoch 67 average loss: 0.0267
# Stepped scheduler to epoch 67, current lr: [0.0007898305084745763]
# ----------
# epoch 68/300
# epoch 68 average loss: 0.0257
# Stepped scheduler to epoch 68, current lr: [0.0007864406779661018]
# Validation loss: 0.2167
# ----------
# epoch 69/300
# epoch 69 average loss: 0.0249
# Stepped scheduler to epoch 69, current lr: [0.0007830508474576272]
# ----------
# epoch 70/300
# epoch 70 average loss: 0.0250
# Stepped scheduler to epoch 70, current lr: [0.0007796610169491525]
# Validation loss: 0.2257
# ----------
# epoch 71/300
# epoch 71 average loss: 0.0248
# Stepped scheduler to epoch 71, current lr: [0.0007762711864406779]
# ----------
# epoch 72/300
# epoch 72 average loss: 0.0247
# Stepped scheduler to epoch 72, current lr: [0.0007728813559322034]
# Validation loss: 0.2193
# ----------
# epoch 73/300
# epoch 73 average loss: 0.0277
# Stepped scheduler to epoch 73, current lr: [0.0007694915254237288]
# ----------
# epoch 74/300
# epoch 74 average loss: 0.0269
# Stepped scheduler to epoch 74, current lr: [0.0007661016949152543]
# Validation loss: 0.2220
# ----------
# epoch 75/300
# epoch 75 average loss: 0.0257
# Stepped scheduler to epoch 75, current lr: [0.0007627118644067797]
# ----------
# epoch 76/300
# epoch 76 average loss: 0.0247
# Stepped scheduler to epoch 76, current lr: [0.0007593220338983052]
# Validation loss: 0.2217
# ----------
# epoch 77/300
# epoch 77 average loss: 0.0258
# Stepped scheduler to epoch 77, current lr: [0.0007559322033898304]
# ----------
# epoch 78/300
# epoch 78 average loss: 0.0230
# Stepped scheduler to epoch 78, current lr: [0.0007525423728813559]
# Validation loss: 0.2133
# ----------
# epoch 79/300
# epoch 79 average loss: 0.0232
# Stepped scheduler to epoch 79, current lr: [0.0007491525423728813]
# ----------
# epoch 80/300
# epoch 80 average loss: 0.0224
# Stepped scheduler to epoch 80, current lr: [0.0007457627118644068]
# Validation loss: 0.2247
# ----------
# epoch 81/300
# epoch 81 average loss: 0.0223
# Stepped scheduler to epoch 81, current lr: [0.0007423728813559323]
# ----------
# epoch 82/300
# epoch 82 average loss: 0.0231
# Stepped scheduler to epoch 82, current lr: [0.0007389830508474577]
# Validation loss: 0.2122
# ----------
# epoch 83/300
# epoch 83 average loss: 0.0222
# Stepped scheduler to epoch 83, current lr: [0.000735593220338983]
# ----------
# epoch 84/300
# epoch 84 average loss: 0.0213
# Stepped scheduler to epoch 84, current lr: [0.0007322033898305085]
# Validation loss: 0.2186
# ----------
# epoch 85/300
# epoch 85 average loss: 0.0215
# Stepped scheduler to epoch 85, current lr: [0.0007288135593220339]
# ----------
# epoch 86/300
# epoch 86 average loss: 0.0226
# Stepped scheduler to epoch 86, current lr: [0.0007254237288135593]
# Validation loss: 0.2184
# ----------
# epoch 87/300
# epoch 87 average loss: 0.0282
# Stepped scheduler to epoch 87, current lr: [0.0007220338983050847]
# ----------
# epoch 88/300
# epoch 88 average loss: 0.0229
# Stepped scheduler to epoch 88, current lr: [0.0007186440677966102]
# Validation loss: 0.2202
# ----------
# epoch 89/300
# epoch 89 average loss: 0.0215
# Stepped scheduler to epoch 89, current lr: [0.0007152542372881357]
# ----------
# epoch 90/300
# epoch 90 average loss: 0.0221
# Stepped scheduler to epoch 90, current lr: [0.000711864406779661]
# Validation loss: 0.2105
# ----------
# epoch 91/300
# epoch 91 average loss: 0.0219
# Stepped scheduler to epoch 91, current lr: [0.0007084745762711864]
# ----------
# epoch 92/300
# epoch 92 average loss: 0.0210
# Stepped scheduler to epoch 92, current lr: [0.0007050847457627118]
# Validation loss: 0.2243
# ----------
# epoch 93/300
# epoch 93 average loss: 0.0196
# Stepped scheduler to epoch 93, current lr: [0.0007016949152542373]
# ----------
# epoch 94/300
# epoch 94 average loss: 0.0199
# Stepped scheduler to epoch 94, current lr: [0.0006983050847457627]
# Validation loss: 0.2176
# ----------
# epoch 95/300
# epoch 95 average loss: 0.0191
# Stepped scheduler to epoch 95, current lr: [0.0006949152542372881]
# ----------
# epoch 96/300
# epoch 96 average loss: 0.0193
# Stepped scheduler to epoch 96, current lr: [0.0006915254237288136]
# Validation loss: 0.2155
# ----------
# epoch 97/300
# epoch 97 average loss: 0.0184
# Stepped scheduler to epoch 97, current lr: [0.000688135593220339]
# ----------
# epoch 98/300
# epoch 98 average loss: 0.0194
# Stepped scheduler to epoch 98, current lr: [0.0006847457627118644]
# Validation loss: 0.2192
# ----------
# epoch 99/300
# epoch 99 average loss: 0.0184
# Stepped scheduler to epoch 99, current lr: [0.0006813559322033899]
# ----------
# epoch 100/300
# epoch 100 average loss: 0.0199
# Stepped scheduler to epoch 100, current lr: [0.0006779661016949152]
# Validation loss: 0.2306
# ----------
# epoch 101/300
# epoch 101 average loss: 0.0217
# Stepped scheduler to epoch 101, current lr: [0.0006745762711864407]
# ----------
# epoch 102/300
# epoch 102 average loss: 0.0228
# Stepped scheduler to epoch 102, current lr: [0.0006711864406779662]
# Validation loss: 0.2133
# ----------
# epoch 103/300
# epoch 103 average loss: 0.0188
# Stepped scheduler to epoch 103, current lr: [0.0006677966101694916]
# ----------
# epoch 104/300
# epoch 104 average loss: 0.0169
# Stepped scheduler to epoch 104, current lr: [0.0006644067796610169]
# Validation loss: 0.2163
# ----------
# epoch 105/300
# epoch 105 average loss: 0.0177
# Stepped scheduler to epoch 105, current lr: [0.0006610169491525424]
# ----------
# epoch 106/300
# epoch 106 average loss: 0.0178
# Stepped scheduler to epoch 106, current lr: [0.0006576271186440679]
# Validation loss: 0.2238
# ----------
# epoch 107/300
# epoch 107 average loss: 0.0217
# Stepped scheduler to epoch 107, current lr: [0.0006542372881355933]
# ----------
# epoch 108/300
# epoch 108 average loss: 0.0195
# Stepped scheduler to epoch 108, current lr: [0.0006508474576271186]
# Validation loss: 0.2247
# ----------
# epoch 109/300
# epoch 109 average loss: 0.0183
# Stepped scheduler to epoch 109, current lr: [0.0006474576271186441]
# ----------
# epoch 110/300
# epoch 110 average loss: 0.0171
# Stepped scheduler to epoch 110, current lr: [0.0006440677966101696]
# Validation loss: 0.2202
# ----------
# epoch 111/300
# epoch 111 average loss: 0.0169
# Stepped scheduler to epoch 111, current lr: [0.0006406779661016949]
# ----------
# epoch 112/300
# epoch 112 average loss: 0.0184
# Stepped scheduler to epoch 112, current lr: [0.0006372881355932203]
# Validation loss: 0.2222
# ----------
# epoch 113/300
# epoch 113 average loss: 0.0176
# Stepped scheduler to epoch 113, current lr: [0.0006338983050847458]
# ----------
# epoch 114/300
# epoch 114 average loss: 0.0163
# Stepped scheduler to epoch 114, current lr: [0.0006305084745762713]
# Validation loss: 0.2148
# ----------
# epoch 115/300
# epoch 115 average loss: 0.0169
# Stepped scheduler to epoch 115, current lr: [0.0006271186440677966]
# ----------
# epoch 116/300
# epoch 116 average loss: 0.0175
# Stepped scheduler to epoch 116, current lr: [0.000623728813559322]
# Validation loss: 0.2212
# ----------
# epoch 117/300
# epoch 117 average loss: 0.0182
# Stepped scheduler to epoch 117, current lr: [0.0006203389830508474]
# ----------
# epoch 118/300
# epoch 118 average loss: 0.0181
# Stepped scheduler to epoch 118, current lr: [0.0006169491525423729]
# Validation loss: 0.2323
# ----------
# epoch 119/300
# epoch 119 average loss: 0.0169
# Stepped scheduler to epoch 119, current lr: [0.0006135593220338983]
# ----------
# epoch 120/300
# epoch 120 average loss: 0.0157
# Stepped scheduler to epoch 120, current lr: [0.0006101694915254237]
# Validation loss: 0.2150
# ----------
# epoch 121/300
# epoch 121 average loss: 0.0155
# Stepped scheduler to epoch 121, current lr: [0.0006067796610169492]
# ----------
# epoch 122/300
# epoch 122 average loss: 0.0161
# Stepped scheduler to epoch 122, current lr: [0.0006033898305084747]
# Validation loss: 0.2250
# ----------
# epoch 123/300
# epoch 123 average loss: 0.0169
# Stepped scheduler to epoch 123, current lr: [0.0006]
# ----------
# epoch 124/300
# epoch 124 average loss: 0.0177
# Stepped scheduler to epoch 124, current lr: [0.0005966101694915253]
# Validation loss: 0.2193
# ----------
# epoch 125/300
# epoch 125 average loss: 0.0167
# Stepped scheduler to epoch 125, current lr: [0.0005932203389830508]
# ----------
# epoch 126/300
# epoch 126 average loss: 0.0156
# Stepped scheduler to epoch 126, current lr: [0.0005898305084745763]
# Validation loss: 0.2194
# ----------
# epoch 127/300
# epoch 127 average loss: 0.0148
# Stepped scheduler to epoch 127, current lr: [0.0005864406779661018]
# ----------
# epoch 128/300
# epoch 128 average loss: 0.0151
# Stepped scheduler to epoch 128, current lr: [0.0005830508474576272]
# Validation loss: 0.2203
# ----------
# epoch 129/300
# epoch 129 average loss: 0.0154
# Stepped scheduler to epoch 129, current lr: [0.0005796610169491526]
# ----------
# epoch 130/300
# epoch 130 average loss: 0.0157
# Stepped scheduler to epoch 130, current lr: [0.0005762711864406779]
# Validation loss: 0.2234
# ----------
# epoch 131/300
# epoch 131 average loss: 0.0178
# Stepped scheduler to epoch 131, current lr: [0.0005728813559322034]
# ----------
# epoch 132/300
# epoch 132 average loss: 0.0147
# Stepped scheduler to epoch 132, current lr: [0.0005694915254237288]
# Validation loss: 0.2201
# ----------
# epoch 133/300
# epoch 133 average loss: 0.0145
# Stepped scheduler to epoch 133, current lr: [0.0005661016949152542]
# ----------
# epoch 134/300
# epoch 134 average loss: 0.0139
# Stepped scheduler to epoch 134, current lr: [0.0005627118644067797]
# Validation loss: 0.2152
# ----------
# epoch 135/300
# epoch 135 average loss: 0.0136
# Stepped scheduler to epoch 135, current lr: [0.0005593220338983052]
# ----------
# epoch 136/300
# epoch 136 average loss: 0.0133
# Stepped scheduler to epoch 136, current lr: [0.0005559322033898306]
# Validation loss: 0.2206
# ----------
# epoch 137/300
# epoch 137 average loss: 0.0145
# Stepped scheduler to epoch 137, current lr: [0.0005525423728813559]
# ----------
# epoch 138/300
# epoch 138 average loss: 0.0150
# Stepped scheduler to epoch 138, current lr: [0.0005491525423728813]
# Validation loss: 0.2127
# ----------
# epoch 139/300
# epoch 139 average loss: 0.0153
# Stepped scheduler to epoch 139, current lr: [0.0005457627118644068]
# ----------
# epoch 140/300
# epoch 140 average loss: 0.0150
# Stepped scheduler to epoch 140, current lr: [0.0005423728813559322]
# Validation loss: 0.2234
# ----------
# epoch 141/300
# epoch 141 average loss: 0.0146
# Stepped scheduler to epoch 141, current lr: [0.0005389830508474576]
# ----------
# epoch 142/300
# epoch 142 average loss: 0.0134
# Stepped scheduler to epoch 142, current lr: [0.0005355932203389831]
# Validation loss: 0.2151
# ----------
# epoch 143/300
# epoch 143 average loss: 0.0131
# Stepped scheduler to epoch 143, current lr: [0.0005322033898305086]
# ----------
# epoch 144/300
# epoch 144 average loss: 0.0130
# Stepped scheduler to epoch 144, current lr: [0.0005288135593220339]
# Validation loss: 0.2208
# ----------
# epoch 145/300
# epoch 145 average loss: 0.0136
# Stepped scheduler to epoch 145, current lr: [0.0005254237288135592]
# ----------
# epoch 146/300
# epoch 146 average loss: 0.0136
# Stepped scheduler to epoch 146, current lr: [0.0005220338983050847]
# Validation loss: 0.2206
# ----------
# epoch 147/300
# epoch 147 average loss: 0.0138
# Stepped scheduler to epoch 147, current lr: [0.0005186440677966102]
# ----------
# epoch 148/300
# epoch 148 average loss: 0.0139
# Stepped scheduler to epoch 148, current lr: [0.0005152542372881356]
# Validation loss: 0.2296
# ----------
# epoch 149/300
# epoch 149 average loss: 0.0142
# Stepped scheduler to epoch 149, current lr: [0.000511864406779661]
# ----------
# epoch 150/300
# epoch 150 average loss: 0.0152
# Stepped scheduler to epoch 150, current lr: [0.0005084745762711864]
# Validation loss: 0.2179
# ----------
# epoch 151/300
# epoch 151 average loss: 0.0133
# Stepped scheduler to epoch 151, current lr: [0.0005050847457627119]
# ----------
# epoch 152/300
# epoch 152 average loss: 0.0136
# Stepped scheduler to epoch 152, current lr: [0.0005016949152542373]
# Validation loss: 0.2150
# ----------
# epoch 153/300
# epoch 153 average loss: 0.0128
# Stepped scheduler to epoch 153, current lr: [0.0004983050847457627]
# ----------
# epoch 154/300
# epoch 154 average loss: 0.0126
# Stepped scheduler to epoch 154, current lr: [0.0004949152542372881]
# Validation loss: 0.2252
# ----------
# epoch 155/300
# epoch 155 average loss: 0.0127
# Stepped scheduler to epoch 155, current lr: [0.0004915254237288136]
# ----------
# epoch 156/300
# epoch 156 average loss: 0.0135
# Stepped scheduler to epoch 156, current lr: [0.00048813559322033895]
# Validation loss: 0.2309
# ----------
# epoch 157/300
# epoch 157 average loss: 0.0128
# Stepped scheduler to epoch 157, current lr: [0.00048474576271186445]
# ----------
# epoch 158/300
# epoch 158 average loss: 0.0123
# Stepped scheduler to epoch 158, current lr: [0.0004813559322033898]
# Validation loss: 0.2170
# ----------
# epoch 159/300
# epoch 159 average loss: 0.0127
# Stepped scheduler to epoch 159, current lr: [0.00047796610169491526]
# ----------
# epoch 160/300
# epoch 160 average loss: 0.0119
# Stepped scheduler to epoch 160, current lr: [0.00047457627118644064]
# Validation loss: 0.2182
# ----------
# epoch 161/300
# epoch 161 average loss: 0.0114
# Stepped scheduler to epoch 161, current lr: [0.00047118644067796613]
# ----------
# epoch 162/300
# epoch 162 average loss: 0.0120
# Stepped scheduler to epoch 162, current lr: [0.00046779661016949146]
# Validation loss: 0.2219
# ----------
# epoch 163/300
# epoch 163 average loss: 0.0123
# Stepped scheduler to epoch 163, current lr: [0.00046440677966101695]
# ----------
# epoch 164/300
# epoch 164 average loss: 0.0131
# Stepped scheduler to epoch 164, current lr: [0.00046101694915254233]
# Validation loss: 0.2207
# ----------
# epoch 165/300
# epoch 165 average loss: 0.0126
# Stepped scheduler to epoch 165, current lr: [0.0004576271186440678]
# ----------
# epoch 166/300
# epoch 166 average loss: 0.0119
# Stepped scheduler to epoch 166, current lr: [0.00045423728813559326]
# Validation loss: 0.2223
# ----------
# epoch 167/300
# epoch 167 average loss: 0.0120
# Stepped scheduler to epoch 167, current lr: [0.00045084745762711864]
# ----------
# epoch 168/300
# epoch 168 average loss: 0.0131
# Stepped scheduler to epoch 168, current lr: [0.00044745762711864413]
# Validation loss: 0.2258
# ----------
# epoch 169/300
# epoch 169 average loss: 0.0128
# Stepped scheduler to epoch 169, current lr: [0.0004440677966101695]
# ----------
# epoch 170/300
# epoch 170 average loss: 0.0112
# Stepped scheduler to epoch 170, current lr: [0.00044067796610169495]
# Validation loss: 0.2215
# ----------
# epoch 171/300
# epoch 171 average loss: 0.0112
# Stepped scheduler to epoch 171, current lr: [0.00043728813559322033]
# ----------
# epoch 172/300
# epoch 172 average loss: 0.0112
# Stepped scheduler to epoch 172, current lr: [0.0004338983050847458]
# Validation loss: 0.2244
# ----------
# epoch 173/300
# epoch 173 average loss: 0.0110
# Stepped scheduler to epoch 173, current lr: [0.0004305084745762712]
# ----------
# epoch 174/300
# epoch 174 average loss: 0.0108
# Stepped scheduler to epoch 174, current lr: [0.00042711864406779664]
# Validation loss: 0.2224
# ----------
# epoch 175/300
# epoch 175 average loss: 0.0109
# Stepped scheduler to epoch 175, current lr: [0.000423728813559322]
# ----------
# epoch 176/300
# epoch 176 average loss: 0.0116
# Stepped scheduler to epoch 176, current lr: [0.0004203389830508475]
# Validation loss: 0.2209
# ----------
# epoch 177/300
# epoch 177 average loss: 0.0116
# Stepped scheduler to epoch 177, current lr: [0.0004169491525423729]
# ----------
# epoch 178/300
# epoch 178 average loss: 0.0116
# Stepped scheduler to epoch 178, current lr: [0.00041355932203389833]
# Validation loss: 0.2261
# ----------
# epoch 179/300
# epoch 179 average loss: 0.0122
# Stepped scheduler to epoch 179, current lr: [0.0004101694915254237]
# ----------
# epoch 180/300
# epoch 180 average loss: 0.0125
# Stepped scheduler to epoch 180, current lr: [0.0004067796610169492]
# Validation loss: 0.2218
# ----------
# epoch 181/300
# epoch 181 average loss: 0.0115
# Stepped scheduler to epoch 181, current lr: [0.00040338983050847453]
# ----------
# epoch 182/300
# epoch 182 average loss: 0.0108
# Stepped scheduler to epoch 182, current lr: [0.0004]
# Validation loss: 0.2260
# ----------
# epoch 183/300
# epoch 183 average loss: 0.0104
# Stepped scheduler to epoch 183, current lr: [0.0003966101694915254]
# ----------
# epoch 184/300
# epoch 184 average loss: 0.0102
# Stepped scheduler to epoch 184, current lr: [0.0003932203389830509]
# Validation loss: 0.2266
# ----------
# epoch 185/300
# epoch 185 average loss: 0.0109
# Stepped scheduler to epoch 185, current lr: [0.0003898305084745762]
# ----------
# epoch 186/300
# epoch 186 average loss: 0.0104
# Stepped scheduler to epoch 186, current lr: [0.0003864406779661017]
# Validation loss: 0.2294
# ----------
# epoch 187/300
# epoch 187 average loss: 0.0101
# Stepped scheduler to epoch 187, current lr: [0.0003830508474576271]
# ----------
# epoch 188/300
# epoch 188 average loss: 0.0102
# Stepped scheduler to epoch 188, current lr: [0.0003796610169491526]
# Validation loss: 0.2324
# ----------
# epoch 189/300
# epoch 189 average loss: 0.0108
# Stepped scheduler to epoch 189, current lr: [0.0003762711864406779]
# ----------
# epoch 190/300
# epoch 190 average loss: 0.0111
# Stepped scheduler to epoch 190, current lr: [0.0003728813559322034]
# Validation loss: 0.2306
# ----------
# epoch 191/300
# epoch 191 average loss: 0.0109
# Stepped scheduler to epoch 191, current lr: [0.0003694915254237288]
# ----------
# epoch 192/300
# epoch 192 average loss: 0.0103
# Stepped scheduler to epoch 192, current lr: [0.00036610169491525427]
# Validation loss: 0.2281
# ----------
# epoch 193/300
# epoch 193 average loss: 0.0099
# Stepped scheduler to epoch 193, current lr: [0.0003627118644067797]
# ----------
# epoch 194/300
# epoch 194 average loss: 0.0100
# Stepped scheduler to epoch 194, current lr: [0.0003593220338983051]
# Validation loss: 0.2284
# ----------
# epoch 195/300
# epoch 195 average loss: 0.0102
# Stepped scheduler to epoch 195, current lr: [0.0003559322033898306]
# ----------
# epoch 196/300
# epoch 196 average loss: 0.0102
# Stepped scheduler to epoch 196, current lr: [0.0003525423728813559]
# Validation loss: 0.2264
# ----------
# epoch 197/300
# epoch 197 average loss: 0.0102
# Stepped scheduler to epoch 197, current lr: [0.0003491525423728814]
# ----------
# epoch 198/300
# epoch 198 average loss: 0.0103
# Stepped scheduler to epoch 198, current lr: [0.0003457627118644068]
# Validation loss: 0.2263
# ----------
# epoch 199/300
# epoch 199 average loss: 0.0103
# Stepped scheduler to epoch 199, current lr: [0.00034237288135593227]
# ----------
# epoch 200/300
# epoch 200 average loss: 0.0104
# Stepped scheduler to epoch 200, current lr: [0.0003389830508474576]
# Validation loss: 0.2282
# ----------
# epoch 201/300
# epoch 201 average loss: 0.0101
# Stepped scheduler to epoch 201, current lr: [0.0003355932203389831]
# ----------
# epoch 202/300
# epoch 202 average loss: 0.0102
# Stepped scheduler to epoch 202, current lr: [0.00033220338983050847]
# Validation loss: 0.2263
# ----------
# epoch 203/300
# epoch 203 average loss: 0.0096
# Stepped scheduler to epoch 203, current lr: [0.00032881355932203396]
# ----------
# epoch 204/300
# epoch 204 average loss: 0.0094
# Stepped scheduler to epoch 204, current lr: [0.0003254237288135593]
# Validation loss: 0.2295
# ----------
# epoch 205/300
# epoch 205 average loss: 0.0092
# Stepped scheduler to epoch 205, current lr: [0.0003220338983050848]
# ----------
# epoch 206/300
# epoch 206 average loss: 0.0092
# Stepped scheduler to epoch 206, current lr: [0.00031864406779661016]
# Validation loss: 0.2264
# ----------
# epoch 207/300
# epoch 207 average loss: 0.0093
# Stepped scheduler to epoch 207, current lr: [0.00031525423728813565]
# ----------
# epoch 208/300
# epoch 208 average loss: 0.0099
# Stepped scheduler to epoch 208, current lr: [0.000311864406779661]
# Validation loss: 0.2346
# ----------
# epoch 209/300
# epoch 209 average loss: 0.0103
# Stepped scheduler to epoch 209, current lr: [0.00030847457627118647]
# ----------
# epoch 210/300
# epoch 210 average loss: 0.0101
# Stepped scheduler to epoch 210, current lr: [0.00030508474576271185]
# Validation loss: 0.2363
# ----------
# epoch 211/300
# epoch 211 average loss: 0.0102
# Stepped scheduler to epoch 211, current lr: [0.00030169491525423734]
# ----------
# epoch 212/300
# epoch 212 average loss: 0.0098
# Stepped scheduler to epoch 212, current lr: [0.00029830508474576266]
# Validation loss: 0.2291
# ----------
# epoch 213/300
# epoch 213 average loss: 0.0092
# Stepped scheduler to epoch 213, current lr: [0.00029491525423728815]
# ----------
# epoch 214/300
# epoch 214 average loss: 0.0091
# Stepped scheduler to epoch 214, current lr: [0.00029152542372881354]
# Validation loss: 0.2320
# ----------
# epoch 215/300
# epoch 215 average loss: 0.0091
# Stepped scheduler to epoch 215, current lr: [0.00028813559322033897]
# ----------
# epoch 216/300
# epoch 216 average loss: 0.0089
# Stepped scheduler to epoch 216, current lr: [0.00028474576271186435]
# Validation loss: 0.2324
# ----------
# epoch 217/300
# epoch 217 average loss: 0.0089
# Stepped scheduler to epoch 217, current lr: [0.00028135593220338984]
# ----------
# epoch 218/300
# epoch 218 average loss: 0.0089
# Stepped scheduler to epoch 218, current lr: [0.0002779661016949152]
# Validation loss: 0.2325
# ----------
# epoch 219/300
# epoch 219 average loss: 0.0088
# Stepped scheduler to epoch 219, current lr: [0.00027457627118644066]
# ----------
# epoch 220/300
# epoch 220 average loss: 0.0087
# Stepped scheduler to epoch 220, current lr: [0.00027118644067796615]
# Validation loss: 0.2328
# ----------
# epoch 221/300
# epoch 221 average loss: 0.0088
# Stepped scheduler to epoch 221, current lr: [0.00026779661016949153]
# ----------
# epoch 222/300
# epoch 222 average loss: 0.0089
# Stepped scheduler to epoch 222, current lr: [0.000264406779661017]
# Validation loss: 0.2302
# ----------
# epoch 223/300
# epoch 223 average loss: 0.0091
# Stepped scheduler to epoch 223, current lr: [0.00026101694915254235]
# ----------
# epoch 224/300
# epoch 224 average loss: 0.0094
# Stepped scheduler to epoch 224, current lr: [0.00025762711864406784]
# Validation loss: 0.2321
# ----------
# epoch 225/300
# epoch 225 average loss: 0.0093
# Stepped scheduler to epoch 225, current lr: [0.0002542372881355932]
# ----------
# epoch 226/300
# epoch 226 average loss: 0.0088
# Stepped scheduler to epoch 226, current lr: [0.0002508474576271187]
# Validation loss: 0.2314
# ----------
# epoch 227/300
# epoch 227 average loss: 0.0086
# Stepped scheduler to epoch 227, current lr: [0.00024745762711864404]
# ----------
# epoch 228/300
# epoch 228 average loss: 0.0084
# Stepped scheduler to epoch 228, current lr: [0.00024406779661016953]
# Validation loss: 0.2343
# ----------
# epoch 229/300
# epoch 229 average loss: 0.0083
# Stepped scheduler to epoch 229, current lr: [0.0002406779661016949]
# ----------
# epoch 230/300
# epoch 230 average loss: 0.0082
# Stepped scheduler to epoch 230, current lr: [0.00023728813559322038]
# Validation loss: 0.2323
# ----------
# epoch 231/300
# epoch 231 average loss: 0.0082
# Stepped scheduler to epoch 231, current lr: [0.00023389830508474573]
# ----------
# epoch 232/300
# epoch 232 average loss: 0.0085
# Stepped scheduler to epoch 232, current lr: [0.00023050847457627122]
# Validation loss: 0.2291
# ----------
# epoch 233/300
# epoch 233 average loss: 0.0086
# Stepped scheduler to epoch 233, current lr: [0.00022711864406779658]
# ----------
# epoch 234/300
# epoch 234 average loss: 0.0087
# Stepped scheduler to epoch 234, current lr: [0.00022372881355932207]
# Validation loss: 0.2313
# ----------
# epoch 235/300
# epoch 235 average loss: 0.0091
# Stepped scheduler to epoch 235, current lr: [0.00022033898305084742]
# ----------
# epoch 236/300
# epoch 236 average loss: 0.0089
# Stepped scheduler to epoch 236, current lr: [0.0002169491525423729]
# Validation loss: 0.2322
# ----------
# epoch 237/300
# epoch 237 average loss: 0.0087
# Stepped scheduler to epoch 237, current lr: [0.00021355932203389827]
# ----------
# epoch 238/300
# epoch 238 average loss: 0.0083
# Stepped scheduler to epoch 238, current lr: [0.00021016949152542376]
# Validation loss: 0.2324
# ----------
# epoch 239/300
# epoch 239 average loss: 0.0080
# Stepped scheduler to epoch 239, current lr: [0.0002067796610169491]
# ----------
# epoch 240/300
# epoch 240 average loss: 0.0082
# Stepped scheduler to epoch 240, current lr: [0.0002033898305084746]
# Validation loss: 0.2343
# ----------
# epoch 241/300
# epoch 241 average loss: 0.0083
# Stepped scheduler to epoch 241, current lr: [0.00019999999999999996]
# ----------
# epoch 242/300
# epoch 242 average loss: 0.0081
# Stepped scheduler to epoch 242, current lr: [0.00019661016949152545]
# Validation loss: 0.2346
# ----------
# epoch 243/300
# epoch 243 average loss: 0.0081
# Stepped scheduler to epoch 243, current lr: [0.0001932203389830508]
# ----------
# epoch 244/300
# epoch 244 average loss: 0.0080
# Stepped scheduler to epoch 244, current lr: [0.0001898305084745763]
# Validation loss: 0.2325
# ----------
# epoch 245/300
# epoch 245 average loss: 0.0080
# Stepped scheduler to epoch 245, current lr: [0.00018644067796610165]
# ----------
# epoch 246/300
# epoch 246 average loss: 0.0079
# Stepped scheduler to epoch 246, current lr: [0.00018305084745762714]
# Validation loss: 0.2372
# ----------
# epoch 247/300
# epoch 247 average loss: 0.0079
# Stepped scheduler to epoch 247, current lr: [0.0001796610169491526]
# ----------
# epoch 248/300
# epoch 248 average loss: 0.0079
# Stepped scheduler to epoch 248, current lr: [0.00017627118644067795]
# Validation loss: 0.2374
# ----------
# epoch 249/300
# epoch 249 average loss: 0.0080
# Stepped scheduler to epoch 249, current lr: [0.00017288135593220344]
# ----------
# epoch 250/300
# epoch 250 average loss: 0.0082
# Stepped scheduler to epoch 250, current lr: [0.0001694915254237288]
# Validation loss: 0.2322
# ----------
# epoch 251/300
# epoch 251 average loss: 0.0083
# Stepped scheduler to epoch 251, current lr: [0.0001661016949152543]
# ----------
# epoch 252/300
# epoch 252 average loss: 0.0081
# Stepped scheduler to epoch 252, current lr: [0.00016271186440677964]
# Validation loss: 0.2346
# ----------
# epoch 253/300
# epoch 253 average loss: 0.0081
# Stepped scheduler to epoch 253, current lr: [0.00015932203389830513]
# ----------
# epoch 254/300
# epoch 254 average loss: 0.0081
# Stepped scheduler to epoch 254, current lr: [0.0001559322033898305]
# Validation loss: 0.2386
# ----------
# epoch 255/300
# epoch 255 average loss: 0.0079
# Stepped scheduler to epoch 255, current lr: [0.00015254237288135598]
# ----------
# epoch 256/300
# epoch 256 average loss: 0.0077
# Stepped scheduler to epoch 256, current lr: [0.00014915254237288133]
# Validation loss: 0.2336
# ----------
# epoch 257/300
# epoch 257 average loss: 0.0076
# Stepped scheduler to epoch 257, current lr: [0.00014576271186440682]
# ----------
# epoch 258/300
# epoch 258 average loss: 0.0077
# Stepped scheduler to epoch 258, current lr: [0.00014237288135593218]
# Validation loss: 0.2383
# ----------
# epoch 259/300
# epoch 259 average loss: 0.0076
# Stepped scheduler to epoch 259, current lr: [0.00013898305084745767]
# ----------
# epoch 260/300
# epoch 260 average loss: 0.0075
# Stepped scheduler to epoch 260, current lr: [0.00013559322033898302]
# Validation loss: 0.2365
# ----------
# epoch 261/300
# epoch 261 average loss: 0.0075
# Stepped scheduler to epoch 261, current lr: [0.0001322033898305085]
# ----------
# epoch 262/300
# epoch 262 average loss: 0.0075
# Stepped scheduler to epoch 262, current lr: [0.00012881355932203387]
# Validation loss: 0.2356
# ----------
# epoch 263/300
# epoch 263 average loss: 0.0075
# Stepped scheduler to epoch 263, current lr: [0.00012542372881355936]
# ----------
# epoch 264/300
# epoch 264 average loss: 0.0075
# Stepped scheduler to epoch 264, current lr: [0.00012203389830508471]
# Validation loss: 0.2377
# ----------
# epoch 265/300
# epoch 265 average loss: 0.0074
# Stepped scheduler to epoch 265, current lr: [0.00011864406779661019]
# ----------
# epoch 266/300
# epoch 266 average loss: 0.0074
# Stepped scheduler to epoch 266, current lr: [0.00011525423728813556]
# Validation loss: 0.2376
# ----------
# epoch 267/300
# epoch 267 average loss: 0.0074
# Stepped scheduler to epoch 267, current lr: [0.00011186440677966103]
# ----------
# epoch 268/300
# epoch 268 average loss: 0.0075
# Stepped scheduler to epoch 268, current lr: [0.0001084745762711864]
# Validation loss: 0.2350
# ----------
# epoch 269/300
# epoch 269 average loss: 0.0074
# Stepped scheduler to epoch 269, current lr: [0.00010508474576271188]
# ----------
# epoch 270/300
# epoch 270 average loss: 0.0074
# Stepped scheduler to epoch 270, current lr: [0.00010169491525423725]
# Validation loss: 0.2373
# ----------
# epoch 271/300
# epoch 271 average loss: 0.0074
# Stepped scheduler to epoch 271, current lr: [9.830508474576272e-05]
# ----------
# epoch 272/300
# epoch 272 average loss: 0.0074
# Stepped scheduler to epoch 272, current lr: [9.491525423728809e-05]
# Validation loss: 0.2385
# ----------
# epoch 273/300
# epoch 273 average loss: 0.0074
# Stepped scheduler to epoch 273, current lr: [9.152542372881357e-05]
# ----------
# epoch 274/300
# epoch 274 average loss: 0.0074
# Stepped scheduler to epoch 274, current lr: [8.813559322033904e-05]
# Validation loss: 0.2374
# ----------
# epoch 275/300
# epoch 275 average loss: 0.0074
# Stepped scheduler to epoch 275, current lr: [8.47457627118644e-05]
# ----------
# epoch 276/300
# epoch 276 average loss: 0.0074
# Stepped scheduler to epoch 276, current lr: [8.135593220338988e-05]
# Validation loss: 0.2387
# ----------
# epoch 277/300
# epoch 277 average loss: 0.0073
# Stepped scheduler to epoch 277, current lr: [7.796610169491524e-05]
# ----------
# epoch 278/300
# epoch 278 average loss: 0.0073
# Stepped scheduler to epoch 278, current lr: [7.457627118644072e-05]
# Validation loss: 0.2394
# ----------
# epoch 279/300
# epoch 279 average loss: 0.0073
# Stepped scheduler to epoch 279, current lr: [7.118644067796609e-05]
# ----------
# epoch 280/300
# epoch 280 average loss: 0.0072
# Stepped scheduler to epoch 280, current lr: [6.779661016949157e-05]
# Validation loss: 0.2388
# ----------
# epoch 281/300
# epoch 281 average loss: 0.0072
# Stepped scheduler to epoch 281, current lr: [6.440677966101693e-05]
# ----------
# epoch 282/300
# epoch 282 average loss: 0.0072
# Stepped scheduler to epoch 282, current lr: [6.101694915254241e-05]
# Validation loss: 0.2407
# ----------
# epoch 283/300
# epoch 283 average loss: 0.0072
# Stepped scheduler to epoch 283, current lr: [5.762711864406778e-05]
# ----------
# epoch 284/300
# epoch 284 average loss: 0.0072
# Stepped scheduler to epoch 284, current lr: [5.4237288135593255e-05]
# Validation loss: 0.2394
# ----------
# epoch 285/300
# epoch 285 average loss: 0.0072
# Stepped scheduler to epoch 285, current lr: [5.084745762711862e-05]
# ----------
# epoch 286/300
# epoch 286 average loss: 0.0072
# Stepped scheduler to epoch 286, current lr: [4.74576271186441e-05]
# Validation loss: 0.2400
# ----------
# epoch 287/300
# epoch 287 average loss: 0.0072
# Stepped scheduler to epoch 287, current lr: [4.406779661016946e-05]
# ----------
# epoch 288/300
# epoch 288 average loss: 0.0072
# Stepped scheduler to epoch 288, current lr: [4.067796610169494e-05]
# Validation loss: 0.2400
# ----------
# epoch 289/300
# epoch 289 average loss: 0.0072
# Stepped scheduler to epoch 289, current lr: [3.7288135593220306e-05]
# ----------
# epoch 290/300
# epoch 290 average loss: 0.0073
# Stepped scheduler to epoch 290, current lr: [3.389830508474578e-05]
# Validation loss: 0.2400
# ----------
# epoch 291/300
# epoch 291 average loss: 0.0073
# Stepped scheduler to epoch 291, current lr: [3.050847457627115e-05]
# ----------
# epoch 292/300
# epoch 292 average loss: 0.0073
# Stepped scheduler to epoch 292, current lr: [2.7118644067796627e-05]
# Validation loss: 0.2399
# ----------
# epoch 293/300
# epoch 293 average loss: 0.0074
# Stepped scheduler to epoch 293, current lr: [2.3728813559321992e-05]
# ----------
# epoch 294/300
# epoch 294 average loss: 0.0074
# Stepped scheduler to epoch 294, current lr: [2.033898305084747e-05]
# Validation loss: 0.2398
# ----------
# epoch 295/300
# epoch 295 average loss: 0.0075
# Stepped scheduler to epoch 295, current lr: [1.6949152542372837e-05]
# ----------
# epoch 296/300
# epoch 296 average loss: 0.0075
# Stepped scheduler to epoch 296, current lr: [1.3559322033898314e-05]
# Validation loss: 0.2399
# ----------
# epoch 297/300
# epoch 297 average loss: 0.0076
# Stepped scheduler to epoch 297, current lr: [1.016949152542368e-05]
# ----------
# epoch 298/300
# epoch 298 average loss: 0.0078
# Stepped scheduler to epoch 298, current lr: [6.779661016949157e-06]
# Validation loss: 0.2410
# ----------
# epoch 299/300
# epoch 299 average loss: 0.0079
# Stepped scheduler to epoch 299, current lr: [3.389830508474523e-06]
# ----------
# epoch 300/300
# epoch 300 average loss: 0.0081
# Stepped scheduler to epoch 300, current lr: [0.0]
# Validation loss: 0.2426

# %%
image, target = (check_data["image"][0][0], check_data["target"][0][0])
print(f"image shape: {image.shape}, target shape: {target.shape}")

plt.figure("check", (12, 6))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(image, cmap="gist_yarg")  # Adjusted to remove the third dimension indexing
plt.subplot(1, 2, 2)
plt.title("target")
plt.imshow(target, cmap='gist_yarg')  # Adjusted to remove the third dimension indexing
plt.show()
# Out:
# image shape: torch.Size([168, 168]), target shape: torch.Size([168, 168])

# %%
def find_last_saved_model(log_filepath):
    last_saved_model = None
    best_metric = None
    epoch = None
    with open(log_filepath, 'r') as file:
        for line in file:
            if "Saved" in line and ".pth" in line:
                parts = line.split(',')
                last_saved_model = parts[0].split()[1]  # Extract model filename
                best_metric = float(parts[1].split(': ')[1])  # Extract best metric
                epoch = int(parts[2].split(': ')[1])  # Extract epoch number
    return last_saved_model, best_metric, epoch


log_filename = 'log_2_23_13_40.txt'
log_filepath = directory + '/'+ log_filename
bestmodel_filename, best_metric, best_epoch = find_last_saved_model(log_filepath)
print(f"Model Filename: {bestmodel_filename}, Best Metric: {best_metric}, Epoch: {best_epoch}")
# Out:
# Model Filename: model_2_23_14_56.pth, Best Metric: 0.206, Epoch: 48

# %%
# Function to parse the loss values from the log file
def parse_loss_values(log_filepath):
    train_losses = []
    val_losses = []
    with open(log_filepath, 'r') as file:
        for line in file:
            if 'average loss:' in line:
                loss_value = float(line.split(': ')[-1])
                train_losses.append(loss_value)
            if 'Validation loss:' in line:
                val_loss_value = float(line.split(': ')[-1])
                val_losses.append(val_loss_value)
    return train_losses, val_losses

# Replace this with the path to your actual log file

train_losses, val_losses = parse_loss_values(log_filepath)

max_epochs = len(train_losses)
val_interval = 2  # Update this if your validation interval is different

# Plotting
plt.figure(figsize=(14, 6))
plt.plot(range(1, max_epochs + 1), train_losses, label='Training Loss', color='blue', alpha=0.9)
plt.plot(range(2, max_epochs + 1, val_interval), val_losses, label='Validation Loss', color='orange', alpha=0.8)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.xticks(np.arange(1, max_epochs + 1, 10))  # Adjust the x-axis ticks if needed
plt.show()

# %%
import torch

# Assuming root_dir is the directory where your model files are stored
model_path = os.path.join(directory, bestmodel_filename)
if os.path.exists(model_path):
    print(f"Model file {bestmodel_filename} is loading.")
    model.load_state_dict(torch.load(model_path))
    model.eval()
else:
    print(f"Model file {bestmodel_filename} not found.")
# Out:
# Model file model_2_23_14_56.pth is loading.

# %%
def visualize_results_whole(data, model, title):
    model.eval()
    # Select a middle slice or any specific slice from the volume
    # slice_idx = data["image"].shape[-1] // 2  # Example for selecting the middle slice
    slice_idx = 50

    with torch.no_grad():
        # Ensure the input is 4D: [batch_size, channels, height, width]
        # Adjust dimensions as needed, e.g., selecting the middle slice
        input_2d = data["image"][..., slice_idx].to(device)  # Adjust indexing if necessary
        model_outputs = model(input_2d)

    plt.figure("check", (18, 6))

    plt.subplot(1, 3, 1)
    plt.title("Input")
    # Adjust the slice selection accordingly
    input_slice = input_2d[0, 0, :, :].cpu().numpy()
    plt.imshow(np.rot90(input_slice), cmap="gist_yarg")

    plt.subplot(1, 3, 2)
    plt.title("Ground_truth")
    # Adjust the slice selection accordingly
    target_slice = data["target"][..., slice_idx][0, 0, :, :].cpu().numpy()
    plt.imshow(np.rot90(target_slice), cmap="gist_yarg")

    plt.subplot(1, 3, 3)
    plt.title(title)
    # Assuming model outputs are [batch_size, channels, height, width]
    output_slice = model_outputs[0, 0, :, :].detach().cpu().numpy()
    plt.imshow(np.rot90(output_slice), cmap="gist_yarg")

    plt.show()



with torch.no_grad():
    for i, data in enumerate(val_loader):
        visualize_results_whole(data, model, f"{bestmodel_filename}\nepoch: {best_epoch}, best_metric: {best_metric}")
        if i == 0:
            break

# %%
# with torch.no_grad():
#     for i, data in enumerate(test_loader):
#         n = 70
#         visualize_results_whole(data, model, n, f"{bestmodel_filename}\nepoch: {best_epoch}, best_metric: {best_metric}")
#         if i == 2:
#             break

# %%
# # Define a function for visualization
# def visualize_results(val_data, model, n, title):

#     val_outputs = sliding_window_inference(val_data["image"].to(device), roi_size,
#                           sw_batch_size, model, progress=True, overlap=0.70) # using ov= 0.9 best image ever I have.


#     plt.figure("check", (12, 6))

#     plt.subplot(1, 3, 1)
#     plt.title(f"Input")
#     input_slice = np.rot90(val_data["image"][0, 0, :, n, :])
#     plt.imshow(input_slice, cmap="gist_yarg")

#     plt.subplot(1, 3, 2)
#     plt.title(f"Ground_truth")
#     target_slice = np.rot90(val_data["target"][0, 0, :, n, :])
#     plt.imshow(target_slice, cmap="gist_yarg")

#     plt.subplot(1, 3, 3)
#     plt.title(title)
#     output_slice = np.rot90(val_outputs.detach().cpu()[0, 0, :, n, :])
#     plt.imshow(output_slice, cmap="gist_yarg")
    
#     plt.show()


# roi_size = (80, 80, 80)
# sw_batch_size = 64 # Increase the overlap by using a higher sw_batch_size
# with torch.no_grad():
#     for i, val_data in enumerate(test_loader):

#         n = 100
#         visualize_results(val_data, model, n, f"{bestmodel_filename},epoch: { best_epoch}, best_metric: {best_metric}")
#         if i == 0:
#             break
# Out:
# 100%|██████████| 31/31 [01:14<00:00,  2.41s/it]
