# %% [markdown]
# <a href="https://colab.research.google.com/github/s-shahpouri/DL_PET/blob/main/PET_Regression_Object_oriented.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup environment

# %%
# !python -c "import monai" || pip install -q "monai-weekly[gdown, nibabel, tqdm, ignite]"
# !python -c "import matplotlib" || pip install -q matplotlib
# !python -c "import pydicom" || pip install pydicom
# !python -c "import dicom2nifti" ||pip install dicom2nifti



from monai.utils import first, set_determinism
from monai.transforms import (EnsureChannelFirstd, Compose, CropForegroundd, LoadImaged, Orientationd, RandCropByPosNegLabeld, ScaleIntensityRanged, Spacingd)
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset
from monai.apps import download_and_extract
from monai.transforms import CenterSpatialCropd
from monai.transforms import Resized
import torch
import matplotlib.pyplot as plt
import os
import glob
import torch.nn as nn
from google.colab import drive
from datetime import datetime
# Out:
# 2024-01-16 08:00:28.965419: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-16 08:00:28.965518: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-16 08:00:28.970293: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-16 08:00:31.733985: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
drive.mount('/content/drive')
data_dir = '/content/drive/My Drive/PET_data/ASC-PET-001'
directory='/content/drive/My Drive/PET_data/LOG'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Set dataset path

# %%
train_images = sorted(glob.glob(os.path.join(data_dir, "NAC", "*.nii.gz")))
target_images = sorted(glob.glob(os.path.join(data_dir, "MAC", "*.nii.gz")))

# data_dicts = [{"image": img, "target": tar} for img in train_images]
data_dicts = [{"image": img, "target": tar} for img, tar in zip(train_images, target_images)]

# making  smaller input to save time for practing stage:
train_files, val_files =  data_dicts[:20], data_dicts[-1:]
# train_files, val_files =  data_dicts[-2:], data_dicts[-1:]

set_determinism(seed=0)

# %%
crop_size = (180, 180, 312)  # Adjusted based on my data

train_transforms = Compose(
    [   LoadImaged(keys=["image", "target"]),
        EnsureChannelFirstd(keys=["image", "target"]),
        Spacingd(keys=["image", "target"], pixdim=(1.5, 1.5, 2.0)),
        Resized(keys=["image", "target"], spatial_size=crop_size, mode='bilinear'),
        # CenterSpatialCropd(keys=["image", "target"], roi_size=crop_size, lazy=True),
    ])

val_transforms = Compose(
    [   LoadImaged(keys=["image", "target"]),
        EnsureChannelFirstd(keys=["image", "target"]),
        Spacingd(keys=["image", "target"], pixdim=(1.5, 1.5, 2.0)),
        Resized(keys=["image", "target"], spatial_size=crop_size, mode=('bilinear')),
        # CenterSpatialCropd(keys=["image", "target"], roi_size=crop_size, lazy=True),

    ])

train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=1)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=1)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=1)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=1)
# Out:
# Loading dataset: 100%|██████████| 20/20 [10:11<00:00, 30.55s/it]
# Loading dataset: 100%|██████████| 1/1 [00:32<00:00, 32.72s/it]

# %%
# Fetch a batch from the train_loader
batch_data = next(iter(train_loader))

# Extract the image and target from the batch
image, target = batch_data['image'], batch_data['target']

# Print their shapes
print("Transformed Image Shape:", image.shape)
print("Transformed Target Shape:", target.shape)
# Out:
# Transformed Image Shape: torch.Size([2, 1, 180, 180, 312])
# Transformed Target Shape: torch.Size([2, 1, 180, 180, 312])

# %%
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, target = (check_data["image"][0][0], check_data["target"][0][0])
print(f"image shape: {image.shape}, target shape: {target.shape}")
# plot the slice [:, :, n]
n = 100

plt.figure("check", (12, 6))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(image[:, :, n], cmap="gist_yarg")
plt.subplot(1, 2, 2)
plt.title("target")
plt.imshow(target[:, :, n],cmap='gist_yarg' )
plt.show()
# Out:
# image shape: torch.Size([180, 180, 312]), target shape: torch.Size([180, 180, 312])

# %% [markdown]
# # **Create Model, Loss, Optimizer**

# %%
import os
import datetime
from datetime import datetime


class TrainingLogger:
    def __init__(self, directory):
        self.directory = directory
        self.ensure_directory_exists(self.directory)
        self.log_file = self.create_log_file()

    def ensure_directory_exists(self, directory):
        if not os.path.exists(directory):
            os.makedirs(directory)

    def create_log_file(self):
        filename = f"{self.directory}/log_{self.get_date()}.txt"
        return open(filename, "w")

    def get_date(self):

        s = datetime.now()
        date = f"{s.month}_{s.day}_{s.hour}_{s.minute}"
        return date

    def log(self, message):
        print(message)
        self.log_file.write(message + "\n")

    def close(self):
        self.log_file.close()

# %%
class ModelTrainer:
    def __init__(self, model, train_loader, val_loader, optimizer, loss_function, max_epochs, val_interval, directory):
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.optimizer = optimizer
        self.loss_function = loss_function
        self.max_epochs = max_epochs
        self.val_interval = val_interval
        self.directory = directory
        self.logger = TrainingLogger(directory)
        self.best_metric = float('inf')
        self.best_metric_epoch = -1


    def log(self):
        self.logger.log(f"train set: {len(train_files)}" )
        self.logger.log(f"validation set: {len(val_files)}")
        self.logger.log(f"max_epochs: {max_epochs}")
        self.logger.log(f"val_interval: {val_interval}")
        self.logger.log(f"model.channels: {model.channels}")


    def train(self):

        for epoch in range(self.max_epochs):
            self.logger.log("-" * 10)
            self.logger.log(f"epoch {epoch + 1}/{self.max_epochs}")

            self.model.train()
            epoch_loss = 0
            step = 0

            for batch_data in self.train_loader:
                step += 1
                inputs, targets = batch_data["image"].to(device), batch_data["target"].to(device)
                self.optimizer.zero_grad()
                outputs = self.model(inputs)
                loss = self.loss_function(outputs, targets)
                loss.backward()
                self.optimizer.step()

                epoch_loss += loss.item()
                train_loss_info = f"{step}/{len(self.train_loader.dataset) // self.train_loader.batch_size}, train_loss: {loss.item():.4f}"
                self.logger.log(train_loss_info)

            # Calculate average loss for the epoch
            epoch_loss /= step
            self.logger.log(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

            # Validation
            if (epoch + 1) % self.val_interval == 0:
                self.model.eval()
                val_loss = 0
                with torch.no_grad():
                    for val_data in self.val_loader:
                        val_inputs, val_targets = val_data["image"].to(device), val_data["target"].to(device)
                        val_outputs = self.model(val_inputs)
                        val_loss += self.loss_function(val_outputs, val_targets).item()

                    val_loss /= len(self.val_loader)
                    self.logger.log(f"Validation loss: {val_loss:.4f}")

                    if val_loss < self.best_metric:
                        self.best_metric = val_loss
                        self.best_metric_epoch = epoch + 1
                        self.save_model()


        self.logger.close()

    def save_model(self):
        model_filename = f"model_{self.logger.get_date()}.pth"
        torch.save(self.model.state_dict(), os.path.join(self.directory, model_filename))
        self.logger.log(f"Saved {model_filename} model, best_metric: {self.best_metric:.4f}, epoch: {self.best_metric_epoch} ")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=1,
    channels=(16, 32, 64),
    # default=[32, 64, 128, 256, 512, 32] MRI Recon
    act=(nn.ReLU6, {"inplace": True}),
    strides=(2, 2),
  num_res_units=2,
    norm=Norm.BATCH,
).to(device)

loss_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-4)

max_epochs = 50
val_interval = 2
best_metric = float('inf')
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
train_losses = []
val_losses = []
trainer = ModelTrainer(model, train_loader, val_loader, optimizer, loss_function, max_epochs, val_interval,directory)
trainer.log()
trainer.train()
# Out:
# train set: 20
# validation set: 1
# max_epochs: 50
# val_interval: 2
# model.channels: (16, 32, 64)
# ----------
# epoch 1/50
# 1/10, train_loss: 0.9095
# 2/10, train_loss: 1.4006
# 3/10, train_loss: 0.9627
# 4/10, train_loss: 0.8512
# 5/10, train_loss: 0.6595
# 6/10, train_loss: 0.6478
# 7/10, train_loss: 0.5567
# 8/10, train_loss: 0.8403
# 9/10, train_loss: 0.9332
# 10/10, train_loss: 0.6396
# epoch 1 average loss: 0.8401
# ----------
# epoch 2/50
# 1/10, train_loss: 0.7749
# 2/10, train_loss: 0.5593
# 3/10, train_loss: 1.0294
# 4/10, train_loss: 0.9581
# 5/10, train_loss: 0.5373
# 6/10, train_loss: 0.7701
# 7/10, train_loss: 0.4968
# 8/10, train_loss: 0.6995
# 9/10, train_loss: 0.5683
# 10/10, train_loss: 0.4714
# epoch 2 average loss: 0.6865
# Validation loss: 0.7685
# Saved model_1_16_8_26.pth model, best_metric: 0.7685, epoch: 2
# ----------
# epoch 3/50
# 1/10, train_loss: 0.6649
# 2/10, train_loss: 0.4497
# 3/10, train_loss: 0.5322
# 4/10, train_loss: 0.7201
# 5/10, train_loss: 0.8252
# 6/10, train_loss: 0.5498
# 7/10, train_loss: 0.7055
# 8/10, train_loss: 0.4474
# 9/10, train_loss: 0.9026
# 10/10, train_loss: 0.5418
# epoch 3 average loss: 0.6339
# ----------
# epoch 4/50
# 1/10, train_loss: 0.6594
# 2/10, train_loss: 0.7512
# 3/10, train_loss: 0.3527
# 4/10, train_loss: 0.4213
# 5/10, train_loss: 0.7954
# 6/10, train_loss: 0.5576
# 7/10, train_loss: 0.4941
# 8/10, train_loss: 0.5472
# 9/10, train_loss: 0.6880
# 10/10, train_loss: 0.7107
# epoch 4 average loss: 0.5978
# Validation loss: 0.6702
# Saved model_1_16_8_42.pth model, best_metric: 0.6702, epoch: 4
# ----------
# epoch 5/50
# 1/10, train_loss: 0.9618
# 2/10, train_loss: 0.3728
# 3/10, train_loss: 0.4411
# 4/10, train_loss: 0.6069
# 5/10, train_loss: 0.5986
# 6/10, train_loss: 0.7084
# 7/10, train_loss: 0.4646
# 8/10, train_loss: 0.6397
# 9/10, train_loss: 0.4110
# 10/10, train_loss: 0.5572
# epoch 5 average loss: 0.5762
# ----------
# epoch 6/50
# 1/10, train_loss: 0.3940
# 2/10, train_loss: 0.3313
# 3/10, train_loss: 0.6310
# 4/10, train_loss: 0.6282
# 5/10, train_loss: 0.4086
# 6/10, train_loss: 0.6828
# 7/10, train_loss: 0.8109
# 8/10, train_loss: 0.4365
# 9/10, train_loss: 0.7601
# 10/10, train_loss: 0.3800
# epoch 6 average loss: 0.5463
# Validation loss: 0.5745
# Saved model_1_16_8_57.pth model, best_metric: 0.5745, epoch: 6
# ----------
# epoch 7/50
# 1/10, train_loss: 0.4382
# 2/10, train_loss: 0.5118
# 3/10, train_loss: 0.8666
# 4/10, train_loss: 0.4337
# 5/10, train_loss: 0.4205
# 6/10, train_loss: 0.6698
# 7/10, train_loss: 0.5689
# 8/10, train_loss: 0.4409
# 9/10, train_loss: 0.4166
# 10/10, train_loss: 0.4702
# epoch 7 average loss: 0.5237
# ----------
# epoch 8/50
# 1/10, train_loss: 0.3621
# 2/10, train_loss: 0.5729
# 3/10, train_loss: 0.3125
# 4/10, train_loss: 0.3206
# 5/10, train_loss: 0.4132
# 6/10, train_loss: 0.8363
# 7/10, train_loss: 0.5515
# 8/10, train_loss: 0.4750
# 9/10, train_loss: 0.4951
# 10/10, train_loss: 0.5791
# epoch 8 average loss: 0.4918
# Validation loss: 0.7097
# ----------
# epoch 9/50
# 1/10, train_loss: 0.3174
# 2/10, train_loss: 0.7707
# 3/10, train_loss: 0.3480
# 4/10, train_loss: 0.5243
# 5/10, train_loss: 0.4830
# 6/10, train_loss: 0.5552
# 7/10, train_loss: 0.4274
# 8/10, train_loss: 0.4241
# 9/10, train_loss: 0.5182
# 10/10, train_loss: 0.3942
# epoch 9 average loss: 0.4763
# ----------
# epoch 10/50
# 1/10, train_loss: 0.4196
# 2/10, train_loss: 0.7226
# 3/10, train_loss: 0.3656
# 4/10, train_loss: 0.3657
# 5/10, train_loss: 0.8631
# 6/10, train_loss: 0.2759
# 7/10, train_loss: 0.2892
# 8/10, train_loss: 0.4356
# 9/10, train_loss: 0.4364
# 10/10, train_loss: 0.3692
# epoch 10 average loss: 0.4543
# Validation loss: 1.0159
# ----------
# epoch 11/50
# 1/10, train_loss: 0.5997
# 2/10, train_loss: 0.5844
# 3/10, train_loss: 0.3584
# 4/10, train_loss: 0.5786
# 5/10, train_loss: 0.3939
# 6/10, train_loss: 0.2816
# 7/10, train_loss: 0.3595
# 8/10, train_loss: 0.2745
# 9/10, train_loss: 0.4962
# 10/10, train_loss: 0.4512
# epoch 11 average loss: 0.4378
# ----------
# epoch 12/50
# 1/10, train_loss: 0.4876
# 2/10, train_loss: 0.6300
# 3/10, train_loss: 0.4385
# 4/10, train_loss: 0.4264
# 5/10, train_loss: 0.3247
# 6/10, train_loss: 0.6283
# 7/10, train_loss: 0.2065
# 8/10, train_loss: 0.3911
# 9/10, train_loss: 0.2752
# 10/10, train_loss: 0.5210
# epoch 12 average loss: 0.4329
# Validation loss: 0.8025
# ----------
# epoch 13/50
# 1/10, train_loss: 0.3264
# 2/10, train_loss: 0.3616
# 3/10, train_loss: 0.6164
# 4/10, train_loss: 0.3676
# 5/10, train_loss: 0.3063
# 6/10, train_loss: 0.5644
# 7/10, train_loss: 0.3357
# 8/10, train_loss: 0.2851
# 9/10, train_loss: 0.5888
# 10/10, train_loss: 0.3919
# epoch 13 average loss: 0.4144
# ----------
# epoch 14/50
# 1/10, train_loss: 0.2865
# 2/10, train_loss: 0.3572
# 3/10, train_loss: 0.5826
# 4/10, train_loss: 0.4412
# 5/10, train_loss: 0.4876
# 6/10, train_loss: 0.4249
# 7/10, train_loss: 0.6044
# 8/10, train_loss: 0.2741
# 9/10, train_loss: 0.3080
# 10/10, train_loss: 0.1819
# epoch 14 average loss: 0.3948
# Validation loss: 1.2194
# ----------
# epoch 15/50
# 1/10, train_loss: 0.4658
# 2/10, train_loss: 0.6324
# 3/10, train_loss: 0.2769
# 4/10, train_loss: 0.3227
# 5/10, train_loss: 0.3446
# 6/10, train_loss: 0.3179
# 7/10, train_loss: 0.3891
# 8/10, train_loss: 0.4654
# 9/10, train_loss: 0.4268
# 10/10, train_loss: 0.2215
# epoch 15 average loss: 0.3863
# ----------
# epoch 16/50
# 1/10, train_loss: 0.2020
# 2/10, train_loss: 0.3814
# 3/10, train_loss: 0.3972
# 4/10, train_loss: 0.6189
# 5/10, train_loss: 0.2287
# 6/10, train_loss: 0.2670
# 7/10, train_loss: 0.5912
# 8/10, train_loss: 0.3807
# 9/10, train_loss: 0.3218
# 10/10, train_loss: 0.3157
# epoch 16 average loss: 0.3705
# Validation loss: 0.6650
# ----------
# epoch 17/50
# 1/10, train_loss: 0.4550
# 2/10, train_loss: 0.1841
# 3/10, train_loss: 0.3165
# 4/10, train_loss: 0.3420
# 5/10, train_loss: 0.6150
# 6/10, train_loss: 0.4432
# 7/10, train_loss: 0.2778
# 8/10, train_loss: 0.2501
# 9/10, train_loss: 0.2640
# 10/10, train_loss: 0.4163
# epoch 17 average loss: 0.3564
# ----------
# epoch 18/50
# 1/10, train_loss: 0.2775
# 2/10, train_loss: 0.1985
# 3/10, train_loss: 0.3190
# 4/10, train_loss: 0.4162
# 5/10, train_loss: 0.2290
# 6/10, train_loss: 0.3197
# 7/10, train_loss: 0.2502
# 8/10, train_loss: 0.5033
# 9/10, train_loss: 0.5152
# 10/10, train_loss: 0.3116
# epoch 18 average loss: 0.3340
# Validation loss: 1.0347
# ----------
# epoch 19/50
# 1/10, train_loss: 0.4256
# 2/10, train_loss: 0.3619
# 3/10, train_loss: 0.2017
# 4/10, train_loss: 0.2529
# 5/10, train_loss: 0.3680
# 6/10, train_loss: 0.2166
# 7/10, train_loss: 0.8004
# 8/10, train_loss: 0.3147
# 9/10, train_loss: 0.2017
# 10/10, train_loss: 0.2426
# epoch 19 average loss: 0.3386
# ----------
# epoch 20/50
# 1/10, train_loss: 0.3867
# 2/10, train_loss: 0.2784
# 3/10, train_loss: 0.1982
# 4/10, train_loss: 0.3029
# 5/10, train_loss: 0.5689
# 6/10, train_loss: 0.3618
# 7/10, train_loss: 0.2875
# 8/10, train_loss: 0.2296
# 9/10, train_loss: 0.3751
# 10/10, train_loss: 0.2039
# epoch 20 average loss: 0.3193
# Validation loss: 0.8997
# ----------
# epoch 21/50
# 1/10, train_loss: 0.3892
# 2/10, train_loss: 0.3062
# 3/10, train_loss: 0.3273
# 4/10, train_loss: 0.2320
# 5/10, train_loss: 0.1553
# 6/10, train_loss: 0.4735
# 7/10, train_loss: 0.3451
# 8/10, train_loss: 0.3414
# 9/10, train_loss: 0.3151
# 10/10, train_loss: 0.2189
# epoch 21 average loss: 0.3104
# ----------
# epoch 22/50
# 1/10, train_loss: 0.2667
# 2/10, train_loss: 0.3806
# 3/10, train_loss: 0.1906
# 4/10, train_loss: 0.2411
# 5/10, train_loss: 0.3625
# 6/10, train_loss: 0.3035
# 7/10, train_loss: 0.2633
# 8/10, train_loss: 0.4634
# 9/10, train_loss: 0.2150
# 10/10, train_loss: 0.3648
# epoch 22 average loss: 0.3052
# Validation loss: 0.8233
# ----------
# epoch 23/50
# 1/10, train_loss: 0.2054
# 2/10, train_loss: 0.4717
# 3/10, train_loss: 0.3646
# 4/10, train_loss: 0.2081
# 5/10, train_loss: 0.2635
# 6/10, train_loss: 0.2871
# 7/10, train_loss: 0.3437
# 8/10, train_loss: 0.3405
# 9/10, train_loss: 0.3084
# 10/10, train_loss: 0.2018
# epoch 23 average loss: 0.2995
# ----------
# epoch 24/50
# 1/10, train_loss: 0.2252
# 2/10, train_loss: 0.4062
# 3/10, train_loss: 0.2316
# 4/10, train_loss: 0.3022
# 5/10, train_loss: 0.3020
# 6/10, train_loss: 0.2533
# 7/10, train_loss: 0.1448
# 8/10, train_loss: 0.5429
# 9/10, train_loss: 0.2813
# 10/10, train_loss: 0.1795
# epoch 24 average loss: 0.2869
# Validation loss: 1.2337
# ----------
# epoch 25/50
# 1/10, train_loss: 0.3279
# 2/10, train_loss: 0.1904
# 3/10, train_loss: 0.2239
# 4/10, train_loss: 0.1956
# 5/10, train_loss: 0.3256
# 6/10, train_loss: 0.2477
# 7/10, train_loss: 0.2610
# 8/10, train_loss: 0.7188
# 9/10, train_loss: 0.2538
# 10/10, train_loss: 0.2285
# epoch 25 average loss: 0.2973
# ----------
# epoch 26/50
# 1/10, train_loss: 0.2385
# 2/10, train_loss: 0.3811
# 3/10, train_loss: 0.3410
# 4/10, train_loss: 0.1601
# 5/10, train_loss: 0.1670
# 6/10, train_loss: 0.4610
# 7/10, train_loss: 0.2729
# 8/10, train_loss: 0.1507
# 9/10, train_loss: 0.2648
# 10/10, train_loss: 0.3162
# epoch 26 average loss: 0.2753
# Validation loss: 1.5948
# ----------
# epoch 27/50
# 1/10, train_loss: 0.2451
# 2/10, train_loss: 0.1558
# 3/10, train_loss: 0.5185
# 4/10, train_loss: 0.2803
# 5/10, train_loss: 0.1746
# 6/10, train_loss: 0.3529
# 7/10, train_loss: 0.1829
# 8/10, train_loss: 0.2520
# 9/10, train_loss: 0.3692
# 10/10, train_loss: 0.3318
# epoch 27 average loss: 0.2863
# ----------
# epoch 28/50
# 1/10, train_loss: 0.1610
# 2/10, train_loss: 0.2862
# 3/10, train_loss: 0.5571
# 4/10, train_loss: 0.1867
# 5/10, train_loss: 0.1588
# 6/10, train_loss: 0.2821
# 7/10, train_loss: 0.3682
# 8/10, train_loss: 0.2732
# 9/10, train_loss: 0.2373
# 10/10, train_loss: 0.2108
# epoch 28 average loss: 0.2722
# Validation loss: 0.9552
# ----------
# epoch 29/50
# 1/10, train_loss: 0.2670
# 2/10, train_loss: 0.2088
# 3/10, train_loss: 0.2441
# 4/10, train_loss: 0.1800
# 5/10, train_loss: 0.2410
# 6/10, train_loss: 0.1546
# 7/10, train_loss: 0.1828
# 8/10, train_loss: 0.5249
# 9/10, train_loss: 0.3181
# 10/10, train_loss: 0.4375
# epoch 29 average loss: 0.2759
# ----------
# epoch 30/50
# 1/10, train_loss: 0.1726
# 2/10, train_loss: 0.1484
# 3/10, train_loss: 0.1768
# 4/10, train_loss: 0.2730
# 5/10, train_loss: 0.2892
# 6/10, train_loss: 0.2487
# 7/10, train_loss: 0.3080
# 8/10, train_loss: 0.2168
# 9/10, train_loss: 0.4772
# 10/10, train_loss: 0.3093
# epoch 30 average loss: 0.2620
# Validation loss: 0.8897
# ----------
# epoch 31/50
# 1/10, train_loss: 0.1671
# 2/10, train_loss: 0.1745
# 3/10, train_loss: 0.1824
# 4/10, train_loss: 0.3413
# 5/10, train_loss: 0.1418
# 6/10, train_loss: 0.5612
# 7/10, train_loss: 0.2531
# 8/10, train_loss: 0.1880
# 9/10, train_loss: 0.3430
# 10/10, train_loss: 0.1974
# epoch 31 average loss: 0.2550
# ----------
# epoch 32/50
# 1/10, train_loss: 0.2343
# 2/10, train_loss: 0.2750
# 3/10, train_loss: 0.1440
# 4/10, train_loss: 0.2232
# 5/10, train_loss: 0.3232
# 6/10, train_loss: 0.2544
# 7/10, train_loss: 0.2291
# 8/10, train_loss: 0.2074
# 9/10, train_loss: 0.2637
# 10/10, train_loss: 0.4492
# epoch 32 average loss: 0.2604
# Validation loss: 2.3816
# ----------
# epoch 33/50
# 1/10, train_loss: 0.2934
# 2/10, train_loss: 0.3907
# 3/10, train_loss: 0.2554
# 4/10, train_loss: 0.1807
# 5/10, train_loss: 0.2832
# 6/10, train_loss: 0.1945
# 7/10, train_loss: 0.1930
# 8/10, train_loss: 0.2141
# 9/10, train_loss: 0.2210
# 10/10, train_loss: 0.2835
# epoch 33 average loss: 0.2510
# ----------
# epoch 34/50
# 1/10, train_loss: 0.1486
# 2/10, train_loss: 0.2186
# 3/10, train_loss: 0.2132
# 4/10, train_loss: 0.1655
# 5/10, train_loss: 0.2261
# 6/10, train_loss: 0.3638
# 7/10, train_loss: 0.1733
# 8/10, train_loss: 0.4386
# 9/10, train_loss: 0.2618
# 10/10, train_loss: 0.2146
# epoch 34 average loss: 0.2424
# Validation loss: 0.8044
# ----------
# epoch 35/50
# 1/10, train_loss: 0.2748
# 2/10, train_loss: 0.3255
# 3/10, train_loss: 0.1791
# 4/10, train_loss: 0.2512
# 5/10, train_loss: 0.2605
# 6/10, train_loss: 0.1912
# 7/10, train_loss: 0.2167
# 8/10, train_loss: 0.1749
# 9/10, train_loss: 0.3662
# 10/10, train_loss: 0.1864
# epoch 35 average loss: 0.2427
# ----------
# epoch 36/50
# 1/10, train_loss: 0.1286
# 2/10, train_loss: 0.4137
# 3/10, train_loss: 0.3078
# 4/10, train_loss: 0.1795
# 5/10, train_loss: 0.2864
# 6/10, train_loss: 0.2458
# 7/10, train_loss: 0.2434
# 8/10, train_loss: 0.2205
# 9/10, train_loss: 0.1747
# 10/10, train_loss: 0.2599
# epoch 36 average loss: 0.2460
# Validation loss: 0.5085
# Saved model_1_16_12_42.pth model, best_metric: 0.5085, epoch: 36
# ----------
# epoch 37/50
# 1/10, train_loss: 0.2629
# 2/10, train_loss: 0.1532
# 3/10, train_loss: 0.2086
# 4/10, train_loss: 0.1517
# 5/10, train_loss: 0.1112
# 6/10, train_loss: 0.3309
# 7/10, train_loss: 0.3470
# 8/10, train_loss: 0.1434
# 9/10, train_loss: 0.4647
# 10/10, train_loss: 0.2895
# epoch 37 average loss: 0.2463
# ----------
# epoch 38/50
# 1/10, train_loss: 0.1704
# 2/10, train_loss: 0.1738
# 3/10, train_loss: 0.1973
# 4/10, train_loss: 0.4371
# 5/10, train_loss: 0.1320
# 6/10, train_loss: 0.3181
# 7/10, train_loss: 0.2084
# 8/10, train_loss: 0.3122
# 9/10, train_loss: 0.2088
# 10/10, train_loss: 0.2497
# epoch 38 average loss: 0.2408
# Validation loss: 3.2262
# ----------
# epoch 39/50
# 1/10, train_loss: 0.1414
# 2/10, train_loss: 0.1505
# 3/10, train_loss: 0.2753
# 4/10, train_loss: 0.1995
# 5/10, train_loss: 0.2026
# 6/10, train_loss: 0.4448
# 7/10, train_loss: 0.2031
# 8/10, train_loss: 0.2484
# 9/10, train_loss: 0.3767
# 10/10, train_loss: 0.1028
# epoch 39 average loss: 0.2345
# ----------
# epoch 40/50
# 1/10, train_loss: 0.2074
# 2/10, train_loss: 0.3142
# 3/10, train_loss: 0.1453
# 4/10, train_loss: 0.1470
# 5/10, train_loss: 0.2410
# 6/10, train_loss: 0.4000
# 7/10, train_loss: 0.1405
# 8/10, train_loss: 0.1278
# 9/10, train_loss: 0.1655
# 10/10, train_loss: 0.4184
# epoch 40 average loss: 0.2307
# Validation loss: 0.7088
# ----------
# epoch 41/50
# 1/10, train_loss: 0.1779
# 2/10, train_loss: 0.4254
# 3/10, train_loss: 0.1541
# 4/10, train_loss: 0.1355
# 5/10, train_loss: 0.3141
# 6/10, train_loss: 0.1856
# 7/10, train_loss: 0.3962
# 8/10, train_loss: 0.1145
# 9/10, train_loss: 0.1676
# 10/10, train_loss: 0.2398
# epoch 41 average loss: 0.2311
# ----------
# epoch 42/50
# 1/10, train_loss: 0.1566
# 2/10, train_loss: 0.2013
# 3/10, train_loss: 0.1154
# 4/10, train_loss: 0.1145
# 5/10, train_loss: 0.4895
# 6/10, train_loss: 0.3201
# 7/10, train_loss: 0.2612
# 8/10, train_loss: 0.1716
# 9/10, train_loss: 0.1997
# 10/10, train_loss: 0.1633
# epoch 42 average loss: 0.2193
# Validation loss: 0.7991
# ----------
# epoch 43/50
# 1/10, train_loss: 0.2527
# 2/10, train_loss: 0.1282
# 3/10, train_loss: 0.1713
# 4/10, train_loss: 0.1894
# 5/10, train_loss: 0.4872
# 6/10, train_loss: 0.2283
# 7/10, train_loss: 0.1511
# 8/10, train_loss: 0.1549
# 9/10, train_loss: 0.1441
# 10/10, train_loss: 0.3016
# epoch 43 average loss: 0.2209
# ----------
# epoch 44/50
# 1/10, train_loss: 0.0944
# 2/10, train_loss: 0.2511
# 3/10, train_loss: 0.1301
# 4/10, train_loss: 0.1750
# 5/10, train_loss: 0.1454
# 6/10, train_loss: 0.2133
# 7/10, train_loss: 0.3448
# 8/10, train_loss: 0.2448
# 9/10, train_loss: 0.2079
# 10/10, train_loss: 0.3476
# epoch 44 average loss: 0.2154
# Validation loss: 1.4148
# ----------
# epoch 45/50
# 1/10, train_loss: 0.2237
# 2/10, train_loss: 0.1289
# 3/10, train_loss: 0.2118
# 4/10, train_loss: 0.1498
# 5/10, train_loss: 0.3870
# 6/10, train_loss: 0.1916
# 7/10, train_loss: 0.1760
# 8/10, train_loss: 0.2553
# 9/10, train_loss: 0.2437
# 10/10, train_loss: 0.1292
# epoch 45 average loss: 0.2097
# ----------
# epoch 46/50
# 1/10, train_loss: 0.1926
# 2/10, train_loss: 0.1622
# 3/10, train_loss: 0.1535
# 4/10, train_loss: 0.2064
# 5/10, train_loss: 0.2258
# 6/10, train_loss: 0.0950
# 7/10, train_loss: 0.2410
# 8/10, train_loss: 0.1564
# 9/10, train_loss: 0.2890
# 10/10, train_loss: 0.3346
# epoch 46 average loss: 0.2056
# Validation loss: 1.4904
# ----------
# epoch 47/50
# 1/10, train_loss: 0.1265
# 2/10, train_loss: 0.1738
# 3/10, train_loss: 0.4181
# 4/10, train_loss: 0.2140
# 5/10, train_loss: 0.1662
# 6/10, train_loss: 0.3393
# 7/10, train_loss: 0.2604
# 8/10, train_loss: 0.1479
# 9/10, train_loss: 0.1268
# 10/10, train_loss: 0.1099
# epoch 47 average loss: 0.2083
# ----------
# epoch 48/50
# 1/10, train_loss: 0.1887
# 2/10, train_loss: 0.2120
# 3/10, train_loss: 0.1316
# 4/10, train_loss: 0.1013
# 5/10, train_loss: 0.2444
# 6/10, train_loss: 0.1814
# 7/10, train_loss: 0.3369
# 8/10, train_loss: 0.1257
# 9/10, train_loss: 0.4138
# 10/10, train_loss: 0.1287
# epoch 48 average loss: 0.2064
# Validation loss: 1.8580
# ----------
# epoch 49/50
# 1/10, train_loss: 0.1483
# 2/10, train_loss: 0.3132
# 3/10, train_loss: 0.1520
# 4/10, train_loss: 0.2479
# 5/10, train_loss: 0.2940
# 6/10, train_loss: 0.1071
# 7/10, train_loss: 0.1995
# 8/10, train_loss: 0.2462
# 9/10, train_loss: 0.1526
# 10/10, train_loss: 0.1243
# epoch 49 average loss: 0.1985
# ----------
# epoch 50/50
# 1/10, train_loss: 0.2023
# 2/10, train_loss: 0.1237
# 3/10, train_loss: 0.1046
# 4/10, train_loss: 0.1824
# 5/10, train_loss: 0.2061
# 6/10, train_loss: 0.4250
# 7/10, train_loss: 0.2484
# 8/10, train_loss: 0.1525
# 9/10, train_loss: 0.2624
# 10/10, train_loss: 0.1369
# epoch 50 average loss: 0.2045
# Validation loss: 1.8085

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to parse the loss values from the log file
def parse_loss_values(log_filepath):
    train_losses = []
    val_losses = []
    with open(log_filepath, 'r') as file:
        for line in file:
            if 'average loss:' in line:
                loss_value = float(line.split(': ')[-1])
                train_losses.append(loss_value)
            if 'Validation loss:' in line:
                val_loss_value = float(line.split(': ')[-1])
                val_losses.append(val_loss_value)
    return train_losses, val_losses

# Replace this with the path to your actual log file

train_losses, val_losses = parse_loss_values(log_filepath)

max_epochs = len(train_losses)
val_interval = 2  # Update this if your validation interval is different

# Plotting
plt.figure(figsize=(14, 6))
plt.plot(range(1, max_epochs + 1), train_losses, label='Training Loss', color='blue', alpha=0.9)
plt.plot(range(2, max_epochs + 1, val_interval), val_losses, label='Validation Loss', color='orange', alpha=0.8)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.xticks(np.arange(1, max_epochs + 1, 1))  # Adjust the x-axis ticks if needed
plt.show()

# %%
def find_last_saved_model(log_filepath):
    last_saved_model = None
    best_metric = None
    epoch = None
    with open(log_filepath, 'r') as file:
        for line in file:
            if "Saved" in line and ".pth" in line:
                parts = line.split(',')
                last_saved_model = parts[0].split()[1]  # Extract model filename
                best_metric = float(parts[1].split(': ')[1])  # Extract best metric
                epoch = int(parts[2].split(': ')[1])  # Extract epoch number
    return last_saved_model, best_metric, epoch


log_filename = 'log_1_16_8_11.txt'
log_filepath = directory + '/'+ log_filename
bestmodel_filename, best_metric, best_epoch = find_last_saved_model(log_filepath)
print(f"Model Filename: {bestmodel_filename}, Best Metric: {best_metric}, Epoch: {best_epoch}")
# Out:
# Model Filename: model_1_16_12_42.pth, Best Metric: 0.5085, Epoch: 36

# %%
import torch

# Assuming root_dir is the directory where your model files are stored
model_path = os.path.join(directory, bestmodel_filename)
if os.path.exists(model_path):
    print(f"Model file {bestmodel_filename} is loading.")
    model.load_state_dict(torch.load(model_path))
    model.eval()
else:
    print(f"Model file {bestmodel_filename} not found.")
# Out:
# Model file model_1_16_12_42.pth is loading.

# %%
# Define a function for visualization
def visualize_results(val_data, model, n, title):

    val_outputs = sliding_window_inference(val_data["image"].to(device), roi_size,
                          sw_batch_size, model, progress=True, overlap=0.70) # using ov= 0.9 best image ever I have.

    plt.figure("check", (18, 6))
    plt.subplot(1, 3, 1)
    plt.title(f"Input")
    plt.imshow(val_data["image"][0, 0, :, :, n], cmap="gist_yarg")

    plt.subplot(1, 3, 2)
    plt.title(f"Target")
    plt.imshow(val_data["target"][0, 0, :, :, n], cmap="gist_yarg")

    plt.subplot(1, 3, 3)
    plt.title(title)
    output_slice = val_outputs.detach().cpu()[0, 0, :, :, n]
    plt.imshow(output_slice, cmap="gist_yarg") # "gist_yarg")
    plt.show()


roi_size = (80, 80, 80)
sw_batch_size = 64 # Increase the overlap by using a higher sw_batch_size
with torch.no_grad():
    for i, val_data in enumerate(val_loader):

        n = 200
        visualize_results(val_data, model, n, f"{bestmodel_filename},epoch: { best_epoch}, best_metric: {best_metric}")
        if i == 0:
            break
# Out:
# 100%|██████████| 7/7 [02:14<00:00, 19.27s/it]

# %%
#         if dice_after > best_eval_dice:
#             best_eval_dice = dice_after
#             if do_save:
#                 # Save best model based on Dice
#                 if pth_best_dice != "":
#                     os.remove(os.path.join(dir_save, pth_best_dice))
#                 pth_best_dice = f"segresnet_kpt_loss_best_dice_{epoch + 1}_{best_eval_dice:.3f}.pth"
#                 torch.save(model.state_dict(), os.path.join(dir_save, pth_best_dice))
#                 print(f"{epoch + 1} | Saving best Dice model: {pth_best_dice}")

#     if do_save:
#         # Save latest model
#         if pth_latest != "":
#             os.remove(os.path.join(dir_save, pth_latest))
#         pth_latest = "segresnet_kpt_loss_latest.pth"
#         torch.save(model.state_dict(), os.path.join(dir_save, pth_latest))


# # learn2reg_nlst_paired_lung_CT notbook
